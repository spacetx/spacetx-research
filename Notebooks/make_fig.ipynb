# %% [markdown]
# ## MULTI DAPI VAE in PYRO

# %% [markdown]
# ### IMPORT NECESSARY MODULES

# %%
# %load_ext autoreload
# %autoreload 2

# %%
#%%bash
#ls

# %%
import os
#os.environ['CUDA_LAUNCH_BLOCKING'] = "1" #for debugging, it decrease performance dramatically

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from MODULES.utilities import show_batch, save_obj, load_obj 
from MODULES.utilities import load_json_as_dict, save_dict_as_json, DatasetInMemory
from MODULES.utilities import train_one_epoch, evaluate_one_epoch, test_model, linear_interpolation
from MODULES.vae_model import CompositionalVae

#!pip install moviepy
from IPython.display import Image, display, HTML
import moviepy.editor as mpy
import numpy as np
import torch
import pyro
from pyro.infer import SVI, Trace_ELBO #,TraceEnum_ELBO, TraceGraph_ELBO, config_enumerate, JitTraceEnum_ELBO 


# Set up pyro environment
pyro.clear_param_store()
pyro.set_rng_seed(0)

# Check versions
print("pyro.__version__  --> ",pyro.__version__)
print("torch.__version__ --> ",torch.__version__)
assert(pyro.__version__.startswith('0.4'))
assert(torch.__version__.startswith('1.2'))
# Out:
# pyro.__version__  -->  0.4.0
# torch.__version__ -->  1.2.0

# %% [markdown]
# # Get the data

# %%
LOCAL_MACHINE=True
if LOCAL_MACHINE:
    batch_size = 4
    data_dir = "/Users/ldalessi/DAPI_unsupervised/DATA/" # for local machine
    write_dir  = '/Users/ldalessi/DAPI_unsupervised/spacetx-research/ARCHIVE/' # local machine
    reference_dir = '/Users/ldalessi/DAPI_unsupervised/DATA/'
else:
    batch_size = 128
    #batch_size = 64
    #batch_size = 32
    
    data_dir = "/home/jupyter/REPOS/spacetx-research/DATA/" # V4
    #write_dir  = '/home/jupyter/REPOS/spacetx-research/ARCHIVE/' # V4
    write_dir  = '/home/jupyter/REPOS/spacetx-research/NEW_ARCHIVE/' # V4
    reference_dir = '/home/jupyter/REPOS/spacetx-research/DATA/REFERENCES/'

# DISK WITH SHADING WITH BG
#train_dataset = DatasetInMemory(data_dir+"DISK_SHADING/","multi_disk_train_shading_bg",use_cuda=torch.cuda.is_available())
#test_dataset  = DatasetInMemory(data_dir+"DISK_SHADING/","multi_disk_test_shading_bg",use_cuda=torch.cuda.is_available())
    
# DISK WITH SHADING WITHOUT BG
#train_dataset = DatasetInMemory(data_dir+"DISK_SHADING/","multi_disk_train_shading",use_cuda=torch.cuda.is_available())
#test_dataset  = DatasetInMemory(data_dir+"DISK_SHADING/","multi_disk_test_shading",use_cuda=torch.cuda.is_available())

# SUPER SMALL MNIST
#train_dataset = DatasetInMemory(data_dir+"MULTI_MNIST/","multi_mnist_train_simple_v3",use_cuda=torch.cuda.is_available())
#test_dataset  = DatasetInMemory(data_dir+"MULTI_MNIST/","multi_mnist_test_simple_v3",use_cuda=torch.cuda.is_available())

# SMALL MNIST
train_dataset = DatasetInMemory(data_dir+"MULTI_MNIST/","multi_mnist_train_with_bg",use_cuda=torch.cuda.is_available())
test_dataset  = DatasetInMemory(data_dir+"MULTI_MNIST/","multi_mnist_test_with_bg",use_cuda=torch.cuda.is_available())

# BIG MNIST
#train_dataset = DatasetInMemory(data_dir+"MULTI_MNIST/","multi_mnist_train_large",use_cuda=torch.cuda.is_available())
#test_dataset  = DatasetInMemory(data_dir+"MULTI_MNIST/","multi_mnist_test_large",use_cuda=torch.cuda.is_available())

# DEBUG FASHION_MNIST
#train_dataset = DatasetInMemory(data_dir+"MULTI_FashionMNIST/","multi_Fashionmnist_train_small_structured_noise",use_cuda=torch.cuda.is_available())
#test_dataset  = DatasetInMemory(data_dir+"MULTI_FashionMNIST/","multi_Fashionmnist_test_small_structured_noise",use_cuda=torch.cuda.is_available())

# REAL FASHION_MNIST
#train_dataset = DatasetInMemory(data_dir+"MULTI_FashionMNIST/","multi_Fashionmnist_train_large_structured_noise",use_cuda=torch.cuda.is_available())
#test_dataset  = DatasetInMemory(data_dir+"MULTI_FashionMNIST/","multi_Fashionmnist_test_large_structured_noise",use_cuda=torch.cuda.is_available())

# DAPI
#train_dataset = DatasetInMemory(data_dir+"DAPI_ONLY_v5/","DAPI_dataset_train",use_cuda=torch.cuda.is_available())
#test_dataset  = DatasetInMemory(data_dir+"DAPI_ONLY_v5/","DAPI_dataset_test",use_cuda=torch.cuda.is_available())

# %%
train_dataset.check()
# Out:
# Dataset lenght: 2000
# imgs.shape torch.Size([8, 1, 80, 80])
# type(imgs) <class 'torch.Tensor'>
# imgs.device cpu
# torch.max(imgs) tensor(1.)
# torch.min(imgs) tensor(0.)

# %%
test_dataset.check()
# Out:
# Dataset lenght: 500
# imgs.shape torch.Size([8, 1, 80, 80])
# type(imgs) <class 'torch.Tensor'>
# imgs.device cpu
# torch.max(imgs) tensor(1.)
# torch.min(imgs) tensor(0.)

# %%
print(test_dataset.labels)
print(torch.min(test_dataset.labels), torch.max(test_dataset.labels))
# Out:
# tensor([2., 2., 2., 4., 2., 2., 3., 3., 2., 2., 4., 3., 4., 2., 3., 3., 2., 3.,
#         2., 2., 2., 2., 3., 3., 2., 4., 3., 3., 3., 3., 2., 3., 2., 2., 2., 2.,
#         1., 3., 3., 4., 1., 2., 1., 2., 2., 2., 2., 2., 3., 4., 2., 3., 3., 3.,
#         2., 2., 3., 3., 3., 2., 2., 3., 5., 4., 3., 1., 2., 3., 2., 3., 3., 3.,
#         4., 3., 1., 4., 3., 3., 3., 3., 2., 3., 3., 3., 4., 3., 2., 2., 3., 2.,
#         3., 3., 2., 2., 2., 2., 2., 3., 4., 3., 3., 3., 3., 2., 3., 3., 3., 3.,
#         3., 4., 2., 3., 2., 3., 3., 3., 2., 2., 2., 2., 2., 3., 3., 4., 3., 2.,
#         4., 5., 2., 3., 4., 4., 3., 3., 3., 3., 4., 2., 2., 4., 4., 3., 2., 4.,
#         4., 3., 2., 4., 2., 2., 3., 3., 4., 3., 2., 4., 2., 2., 2., 2., 1., 3.,
#         4., 3., 2., 3., 3., 3., 4., 2., 2., 4., 3., 3., 2., 3., 2., 2., 2., 4.,
#         4., 2., 2., 3., 2., 3., 3., 3., 2., 1., 2., 4., 4., 5., 4., 3., 2., 1.,
#         1., 3., 3., 4., 3., 3., 2., 3., 3., 1., 4., 3., 2., 3., 3., 2., 3., 4.,
#         3., 1., 3., 3., 2., 3., 2., 3., 3., 2., 3., 4., 3., 2., 3., 3., 2., 2.,
#         2., 3., 3., 2., 2., 3., 3., 2., 3., 2., 2., 3., 4., 2., 3., 3., 3., 3.,
#         3., 2., 4., 3., 2., 2., 2., 2., 2., 4., 3., 2., 2., 5., 3., 2., 2., 3.,
#         2., 3., 3., 2., 3., 3., 3., 3., 3., 2., 2., 2., 2., 2., 3., 3., 2., 3.,
#         3., 4., 3., 3., 2., 3., 2., 4., 2., 2., 2., 3., 3., 2., 2., 3., 2., 2.,
#         4., 3., 1., 2., 2., 3., 3., 2., 3., 2., 3., 3., 3., 3., 3., 3., 3., 3.,
#         2., 3., 2., 2., 2., 3., 2., 2., 2., 3., 3., 4., 3., 2., 3., 2., 3., 2.,
#         3., 2., 3., 2., 2., 5., 3., 4., 3., 2., 4., 2., 3., 3., 3., 2., 3., 3.,
#         3., 4., 3., 3., 3., 2., 2., 3., 2., 3., 2., 2., 3., 3., 2., 2., 2., 1.,
#         3., 3., 2., 3., 2., 4., 3., 3., 2., 3., 2., 2., 2., 2., 3., 2., 3., 2.,
#         2., 3., 3., 3., 1., 3., 2., 3., 2., 2., 2., 3., 2., 4., 3., 2., 2., 3.,
#         3., 4., 3., 2., 3., 3., 3., 1., 3., 3., 3., 3., 3., 3., 2., 2., 4., 2.,
#         3., 3., 3., 3., 3., 3., 3., 2., 2., 2., 2., 2., 3., 2., 3., 3., 3., 2.,
#         4., 2., 2., 1., 4., 4., 3., 3., 2., 1., 3., 3., 3., 2., 2., 2., 3., 2.,
#         3., 3., 5., 3., 2., 2., 2., 3., 2., 3., 3., 2., 4., 3., 2., 3., 3., 3.,
#         2., 3., 2., 2., 3., 3., 4., 3., 3., 2., 2., 1., 2., 4.])
# tensor(1.) tensor(5.)

# %%
#plt.hold(True)

SIZE = 18
plt.rc('font', size=SIZE)
plt.rc('axes', titlesize=SIZE)

plt.xticks(np.arange(0, 7, step=1))
_ = plt.hist([train_dataset.labels.numpy(), test_dataset.labels.numpy()], bins=6, rwidth=0.75, align='left', 
             range=[0,6], stacked=False, density=True, label=["train","test"])
plt.legend()
plt.xlabel("pdf of number of instances")
plt.tight_layout()  # otherwise the right y-label is slightly clipped
plt.savefig("/Users/ldalessi/Desktop/pdf_mnist.png")

# %%
import torch.nn.functional as F

x0= torch.linspace(0,5,4).view(1,1,-1)
x1 = F.interpolate(x0, size=8, mode='linear')
x2 = F.interpolate(x0, size=8, mode='linear', align_corners=True)

print(x0)
print(x1)
print(x2)
plt.plot(x1.view(-1).numpy(), label="align_corners = Default = False")
plt.plot(x2.view(-1).numpy(), label="align_corners = True")
plt.legend()
# Out:
# tensor([[[0.0000, 1.6667, 3.3333, 5.0000]]])
# tensor([[[0.0000, 0.4167, 1.2500, 2.0833, 2.9167, 3.7500, 4.5833, 5.0000]]])
# tensor([[[0.0000, 0.7143, 1.4286, 2.1429, 2.8571, 3.5714, 4.2857, 5.0000]]])

# %% [markdown]
# # OTSU THRESHOLDING

# %%
left = 0.0
right = 1.0
nbins = 50
histo, otsu = test_dataset.compute_otsu_parameters(left = left, right = right, nbins = nbins)
print(otsu)

# Make plot
ch = 0
histo_x = histo.x[ch].cpu().numpy()
histo_y = histo.y[ch].cpu().numpy()
n_th = np.argmin( histo_x < otsu.threshold[ch].cpu().numpy())
plt.plot(histo_x,histo_y, label='empirical histogram')
plt.fill_between(histo_x[:n_th], 0, histo_y[:n_th], facecolor='yellow', alpha=0.5)
plt.fill_between(histo_x[n_th:], 0, histo_y[n_th:], facecolor='red', alpha=0.5)

#plt.ylim(ymin=-0.1, ymax=2.5)
#plt.grid(True)
plt.legend(loc='best')
plt.title("Empirical PDF. Otsu_Threshold = "+str(otsu.threshold[ch].item()))
plt.xlabel("pixel intensity")
plt.savefig("./otsu.png")
# Out:
# Otsu(threshold=tensor([0.5200], device='cuda:0'), bg_mu=tensor([0.2100], device='cuda:0'), bg_std=tensor([0.1052], device='cuda:0'), fg_mu=tensor([0.8291], device='cuda:0'), fg_std=tensor([0.1460], device='cuda:0'), bg_fraction=tensor([0.7299], device='cuda:0'))

# %%
print(otsu.threshold.cpu().item())
# Out:
# 0.5199999809265137

# %%
imgs_in, labels = train_dataset.load(256)
n_fg_pixel = torch.sum((imgs_in > otsu.threshold.cpu().item()).float(), dim=(-1, -2, -3))
w, h = imgs_in.shape[-2:]
fraction_fg_pixel = n_fg_pixel/(w*h)

_ = plt.hist(fraction_fg_pixel.cpu().numpy(), density=True, bins=20)
print("fraction_fg_pixel", n_fg_pixel/(w*h))
# Out:
# fraction_fg_pixel tensor([0.2089, 0.2698, 0.4412, 0.2155, 0.3706, 0.2256, 0.2580, 0.3603, 0.3556,
#         0.2695, 0.2248, 0.2981, 0.2778, 0.3503, 0.3370, 0.4225, 0.2441, 0.1762,
#         0.2455, 0.3041, 0.2208, 0.2080, 0.2836, 0.1669, 0.2497, 0.2820, 0.1634,
#         0.2788, 0.2619, 0.3395, 0.2467, 0.1762, 0.2542, 0.2492, 0.1091, 0.2795,
#         0.2997, 0.2759, 0.3508, 0.3164, 0.3203, 0.3244, 0.2703, 0.2420, 0.3423,
#         0.2833, 0.2530, 0.3139, 0.3081, 0.1834, 0.2592, 0.2370, 0.2859, 0.4225,
#         0.3981, 0.2287, 0.2136, 0.1841, 0.3113, 0.2627, 0.1939, 0.3919, 0.3202,
#         0.1937, 0.3541, 0.2077, 0.3284, 0.2177, 0.2194, 0.1925, 0.2189, 0.3312,
#         0.2700, 0.2517, 0.3125, 0.1986, 0.2927, 0.3627, 0.3202, 0.2216, 0.2642,
#         0.2833, 0.3266, 0.2500, 0.2998, 0.2470, 0.2430, 0.2317, 0.3034, 0.3172,
#         0.2602, 0.2959, 0.2430, 0.2602, 0.3745, 0.2645, 0.2834, 0.2884, 0.2742,
#         0.2419, 0.2077, 0.1617, 0.2934, 0.2625, 0.1867, 0.3302, 0.2233, 0.1686,
#         0.3567, 0.3964, 0.1972, 0.2905, 0.1884, 0.3125, 0.3183, 0.3573, 0.2984,
#         0.2200, 0.2975, 0.3123, 0.2908, 0.2280, 0.3208, 0.2719, 0.1809, 0.2348,
#         0.3527, 0.4198, 0.3717, 0.2975, 0.2339, 0.3166, 0.2037, 0.1445, 0.2962,
#         0.2716, 0.2019, 0.3145, 0.3500, 0.2395, 0.2056, 0.3122, 0.3323, 0.2823,
#         0.3113, 0.3855, 0.3277, 0.2833, 0.3716, 0.2511, 0.2780, 0.2847, 0.2873,
#         0.1175, 0.2283, 0.3750, 0.3606, 0.1536, 0.2586, 0.3281, 0.2616, 0.2352,
#         0.3369, 0.2031, 0.1980, 0.1845, 0.2023, 0.2475, 0.2441, 0.3148, 0.2516,
#         0.2903, 0.3547, 0.3258, 0.2514, 0.1536, 0.2548, 0.3273, 0.2998, 0.2778,
#         0.2847, 0.1489, 0.3436, 0.3289, 0.3300, 0.2569, 0.1762, 0.2556, 0.1492,
#         0.2053, 0.3531, 0.3441, 0.1870, 0.2975, 0.2514, 0.2422, 0.1966, 0.3034,
#         0.2642, 0.2742, 0.2641, 0.3272, 0.2738, 0.2905, 0.1061, 0.2859, 0.1975,
#         0.3308, 0.2306, 0.1825, 0.2758, 0.3698, 0.2266, 0.2355, 0.1392, 0.2169,
#         0.4917, 0.2883, 0.2584, 0.1950, 0.2898, 0.2614, 0.3100, 0.1669, 0.2614,
#         0.3100, 0.2461, 0.2866, 0.2992, 0.1961, 0.2825, 0.2648, 0.2067, 0.2620,
#         0.3031, 0.2659, 0.1698, 0.3025, 0.3047, 0.2816, 0.3395, 0.2003, 0.3070,
#         0.2570, 0.3053, 0.2780, 0.2289, 0.4917, 0.2322, 0.3438, 0.2053, 0.2056,
#         0.2419, 0.3225, 0.3456, 0.3384], device='cuda:0')

# %%
imgs_in, labels = train_dataset.load(8)
print(labels[0])
show_batch(imgs_in[:2])
# Out:
# tensor(4., device='cuda:0')

# %%
if torch.cuda.is_available():
    imgs_in = imgs_in.cuda() 

binarized = (imgs_in > otsu.threshold[...,None, None]).float()
show_batch(binarized, title = "binarized")

# %%
show_batch(imgs_in, title = "Reference")

# %%
size=15
r = test_dataset.compute_brightness_distribution_window(window_size=size,stride=3)
a = plt.hist(r.view(-1), bins=100, range=(0,1),density=True)
plt.title("Empirical PDF")
plt.xlabel("Average intensity in box of size "+str(size))
# Out:
# Text(0.5, 0, 'Average intensity in box of size 15')

# %%
size=35
r = test_dataset.compute_brightness_distribution_window(window_size=size,stride=3)
a = plt.hist(r.view(-1), bins=100, range=(0,1),density=True)
plt.title("Empirical PDF")
plt.xlabel("Average intensity in box of size "+str(size))
# Out:
# Text(0.5, 0, 'Average intensity in box of size 35')

# %% [markdown]
# # Generate the names

# %%
#descriptor        = "MNIST_prob_corr_factor_to_zero_v10_mask_overlap"
#descriptor        = "MNIST_weak_kl_z_strong_kl_p"
#descriptor        = "MNIST_kl_multiplied_by_typical_box_size_v5"
#descriptor        = "MNIST_rerun_v2"
#descriptor        = "sweep_275072"
#descriptor        = "sweep_59969" 
#descriptor        = "MNIST_rerun_v1"
#descriptor        = "MNIST_rerun_v23"  # smaller boxes
#descriptor        = "MNIST_rerun_v3"  # smaller boxes
#descriptor        = "MNIST_tmp5"
#descriptor        = "MNIST_paper_result_6"
#descriptor        = "DISK_final_v3"
#descriptor        = "DAPI_final_v2"
#descriptor        = "DAPI_point_estimate_plus_noise_v23"
descriptor        = "DISK_point_estimate_plus_noise_v62"

name_vae          = descriptor+"_vae"
name_history      = descriptor+"_hystory"
name_hyper_params = descriptor+"_hyper_params"
name_soft_constraints = descriptor+"_soft_constraints"
epoch_restart     = 500
is_restart = False
is_pretrained = False
pyro.clear_param_store()
pyro.set_rng_seed(0)

if(is_restart):

    history_dict = load_obj(write_dir,name_history+"_"+str(epoch_restart))
    
    hyper_params = load_json_as_dict(write_dir,name_hyper_params+"_"+str(epoch_restart))    
    print("")
    print("-HYPER PARAMS-")
    print(hyper_params)
    vae = CompositionalVae.load(hyper_params,write_dir,name_vae+"_"+str(epoch_restart))    
    
    soft_constraints = load_json_as_dict(write_dir, name_soft_constraints+"_"+str(epoch_restart))
   
    # change overlap value
    #soft_constraints["overlap"]["strength"]=10.0
         
    print("")
    print("-CONSTRAINTS-")
    print(soft_constraints)
    vae.dict_soft_constraints = soft_constraints
    
else:    
    
    epoch_restart = -1
    
    min_loss = 99999999
    history_dict = {}
       
    hyper_params=load_json_as_dict("./", "simulation_dictionary")       
    print("")
    print("-HYPER PARAMS-")
    print(hyper_params)
    vae = CompositionalVae(hyper_params)
    vae.reset()
    
    soft_constraints = load_json_as_dict("./", "soft_constraints")
    print("")
    print("-CONSTRAINTS-")
    print(soft_constraints)   
    vae.dict_soft_constraints = soft_constraints
    
    if(is_pretrained):
        storage_dir = "/home/jupyter/REPOS/spacetx-research/NEW_ARCHIVE/PRETRAINED/"
        name_vae_storage = "MNIST_rescale_KL_v51_vae_465"
        vae = CompositionalVae.load(hyper_params,storage_dir,name_vae_storage)
        
save_obj(hyper_params,write_dir,name_hyper_params+"_write_test")
# Out:
# -HYPER PARAMS-
# {'global': {'__comment': 'global parameters', 'dim_zwhat': 25, 'dim_zmask': 25, 'cropped_width': 28}, 'unet': {'__comment': 'parameters of the unet. level_zwhere_output is between 0 and n_max_pool included', 'n_max_pool': 4, 'level_zwhere_output': 2, 'level_background_output': 4, 'n_ch_output_features': 32, 'n_ch_after_first_two_conv': 32}, 'input_image': {'__comment': 'parameters describing the input images', 'n_objects_max': 6, 'size_object_min': 10, 'size_object_max': 35, 'size_object_expected': 20, 'size_raw_image': 80, 'ch_in_description': ['DAPI']}, 'nms': {'__comment': 'parameters for the non-max-suppression', 'score_threshold_test': -1, 'score_threshold_train': -1, 'overlap_threshold_test': 0.3, 'overlap_threshold_train': 0.3, 'randomize_nms_factor_test': 0.2, 'randomize_nms_factor_train': 0.2}, 'noise': {'__comment': 'noise to add in tx, ty, tw, th', 'prob_noise': 0.0, 'tx_noise': 0.0, 'ty_noise': 0.0, 'tw_noise': 0.0, 'th_noise': 0.0}, 'loss': {'__comment': 'parameter of the observation model', 'bg_std': 0.1, 'fg_std': 0.1, 'base_lr': 0.001, 'betas': [0.9, 0.999], 'eps': 1e-08}, 'GECO': {'__comment': 'if active=false use ELBO, else use GECO with Log-Likelihood threshold = n_pixels * n_channel * threshold', 'initial_value': 0.95, 'initial_time': 100, 'goal': [1.2, 1.2], 'times': [100, 500], 'min': 0.05, 'max': 0.95, 'base_lr': 0.001, 'betas': [0.9, 0.999], 'eps': 1e-08}, 'training_prob_corr_factor': {'__comment': 'training protocoll to decay prob_corr_factor', 'values': [0.5, 0.0], 'times': [20, 50]}, 'training_disk_corr_factor': {'__comment': 'training protocoll to decay disk_corr_factor', 'values': [0.5, 0.0], 'times': [20, 50]}}
#
# -CONSTRAINTS-
# {'prob_map_fraction': {'__comment': 'the probability map fraction needs to be in a specific range', 'upper_bound_value': 0.03, 'upper_bound_width': 0.01, 'upper_bound_strength': 0.1, 'upper_bound_exponent': 1}, 'overlap': {'__comment': 'cost which encouranges mask from overlapping', 'strength': 0.01, 'exponent': 1.0}, 'volume_mask_fraction': {'__comment': 'the mask volume fraction should be at least 25%', 'lower_bound_value': 0.2, 'lower_bound_width': 0.05, 'lower_bound_strength': 0.1, 'lower_bound_exponent': 2, 'upper_bound_value': 0.9, 'upper_bound_width': 0.05, 'upper_bound_strength': 0.1, 'upper_bound_exponent': 2}, 'fg_pixel_fraction': {'__comment': 'Fraction of fg_pixel needs to be in a specific range', 'lower_bound_value': 0.03, 'lower_bound_width': 0.02, 'lower_bound_strength': 0.1, 'lower_bound_exponent': 2, 'upper_bound_value': 0.5, 'upper_bound_width': 0.02, 'upper_bound_strength': 0.1, 'upper_bound_exponent': 2}, 'prob_close_to_extremes': {'__comment': 'the probability should not be too close to extremes', 'lower_bound_value': 0.0, 'lower_bound_width': 0.1, 'lower_bound_strength': 0.0, 'lower_bound_exponent': 1, 'upper_bound_value': 1.0, 'upper_bound_width': 0.1, 'upper_bound_strength': 0.0, 'upper_bound_exponent': 2}, 'prob_map_integral': {'__comment': 'the probability map fraction needs to be in a specific range', 'upper_bound_value': 7, 'upper_bound_width': 1.0, 'upper_bound_strength': 0.0, 'upper_bound_exponent': 1}}

# %%
vae.inference_and_generator.unet.describe_receptive_field(imgs_in)
img_with_grid = vae.inference_and_generator.unet.show_grid(imgs_in)
print("img_with_grid.shape",img_with_grid.shape)
show_batch(img_with_grid[:,0])
# Out:
# At layer l=  0  we have w_h_j_rf_wloc_hloc=  (80, 80, 1, 1, 0.5, 0.5)
# At layer l=  1  we have w_h_j_rf_wloc_hloc=  (80, 80, 1.0, 5, 0.5, 0.5)
# At layer l=  2  we have w_h_j_rf_wloc_hloc=  (40, 40, 2.0, 6, 1.0, 1.0)
# At layer l=  3  we have w_h_j_rf_wloc_hloc=  (40, 40, 2.0, 14, 1.0, 1.0)
# At layer l=  4  we have w_h_j_rf_wloc_hloc=  (20, 20, 4.0, 16, 2.0, 2.0)
# At layer l=  5  we have w_h_j_rf_wloc_hloc=  (20, 20, 4.0, 32, 2.0, 2.0)
# At layer l=  6  we have w_h_j_rf_wloc_hloc=  (10, 10, 8.0, 36, 4.0, 4.0)
# At layer l=  7  we have w_h_j_rf_wloc_hloc=  (10, 10, 8.0, 68, 4.0, 4.0)
# At layer l=  8  we have w_h_j_rf_wloc_hloc=  (5, 5, 16.0, 76, 8.0, 8.0)
# At layer l=  9  we have w_h_j_rf_wloc_hloc=  (5, 5, 16.0, 140, 8.0, 8.0)
# At layer l=  10  we have w_h_j_rf_wloc_hloc=  (10, 10, 8.0, 156, 4.0, 4.0)
# At layer l=  11  we have w_h_j_rf_wloc_hloc=  (10, 10, 8.0, 188, 4.0, 4.0)
# At layer l=  12  we have w_h_j_rf_wloc_hloc=  (20, 20, 4.0, 196, 2.0, 2.0)
# At layer l=  13  we have w_h_j_rf_wloc_hloc=  (20, 20, 4.0, 212, 2.0, 2.0)
# At layer l=  14  we have w_h_j_rf_wloc_hloc=  (40, 40, 2.0, 216, 1.0, 1.0)
# At layer l=  15  we have w_h_j_rf_wloc_hloc=  (40, 40, 2.0, 224, 1.0, 1.0)
# At layer l=  16  we have w_h_j_rf_wloc_hloc=  (80, 80, 1.0, 226, 0.5, 0.5)
# At layer l=  17  we have w_h_j_rf_wloc_hloc=  (80, 80, 1.0, 230, 0.5, 0.5)
# img_with_grid.shape torch.Size([9, 8, 1, 80, 80])

# %% [markdown]
# # Check the constraints

# %%
#tmp_dict = vae.dict_soft_constraints['integral_prob_map'] 
#print(tmp_dict)
#vae.dict_soft_constraints['prob_map_integral'] = {}
#vae.dict_soft_constraints['prob_map_integral'] = tmp_dict
#vae.dict_soft_constraints['prob_map_integral'] = tmp 
#vae.dict_soft_constraints
vae.dict_soft_constraints
# Out:
# {'prob_map_fraction': {'__comment': 'the probability map fraction needs to be in a specific range',
#   'upper_bound_value': 0.03,
#   'upper_bound_width': 0.01,
#   'upper_bound_strength': 0.1,
#   'upper_bound_exponent': 1},
#  'overlap': {'__comment': 'cost which encouranges mask from overlapping',
#   'strength': 0.01,
#   'exponent': 1.0},
#  'volume_mask_fraction': {'__comment': 'the mask volume fraction should be at least 25%',
#   'lower_bound_value': 0.2,
#   'lower_bound_width': 0.05,
#   'lower_bound_strength': 0.1,
#   'lower_bound_exponent': 2,
#   'upper_bound_value': 0.9,
#   'upper_bound_width': 0.05,
#   'upper_bound_strength': 0.1,
#   'upper_bound_exponent': 2},
#  'fg_pixel_fraction': {'__comment': 'Fraction of fg_pixel needs to be in a specific range',
#   'lower_bound_value': 0.03,
#   'lower_bound_width': 0.02,
#   'lower_bound_strength': 0.1,
#   'lower_bound_exponent': 2,
#   'upper_bound_value': 0.5,
#   'upper_bound_width': 0.02,
#   'upper_bound_strength': 0.1,
#   'upper_bound_exponent': 2},
#  'prob_close_to_extremes': {'__comment': 'the probability should not be too close to extremes',
#   'lower_bound_value': 0.0,
#   'lower_bound_width': 0.1,
#   'lower_bound_strength': 0.0,
#   'lower_bound_exponent': 1,
#   'upper_bound_value': 1.0,
#   'upper_bound_width': 0.1,
#   'upper_bound_strength': 0.0,
#   'upper_bound_exponent': 2},
#  'prob_map_integral': {'__comment': 'the probability map fraction needs to be in a specific range',
#   'upper_bound_value': 7,
#   'upper_bound_width': 1.0,
#   'upper_bound_strength': 0.0,
#   'upper_bound_exponent': 1}}

# %%
x=torch.linspace(0,1,100)
y=vae.sample_constraints(var_name="prob_close_to_extremes", var_value=x, verbose=False)
plt.plot(x,y)

# %%
x=torch.linspace(0,1,100)
y=vae.sample_constraints(var_name="overlap", var_value=x, verbose=False)
plt.plot(x,y)

# %%
x=torch.linspace(0,1,100)
y=vae.sample_constraints(var_name="volume_mask_fraction", var_value=x, verbose=False)
plt.plot(x,y)

# %%
x=torch.linspace(0,1,101)
y=vae.sample_constraints(var_name="prob_map_fraction", var_value=x, verbose=False)
plt.plot(x,y)
plt.grid()
print()

# %%
x=torch.linspace(0,100,101)
y=vae.sample_constraints(var_name="prob_map_integral", var_value=x, verbose=False)
plt.plot(x,y)
plt.grid()
print()

# %%
x=torch.linspace(0,0.5,100)
y=vae.sample_constraints(var_name="fg_pixel_fraction", var_value=x, verbose=False)
plt.plot(x,y)

# %% [markdown]
# # Nice test to check "constrained" inference

# %%
a = vae.inference_and_generator.unet.forward(imgs_in, verbose=True)
# Out:
# INPUT ---> shape  torch.Size([8, 1, 80, 80])
# input -> output torch.Size([8, 1, 80, 80]) torch.Size([8, 32, 80, 80])
# down    0  shape  torch.Size([8, 32, 80, 80])
# appended
# input -> output torch.Size([8, 32, 80, 80]) torch.Size([8, 64, 40, 40])
# down    1  shape  torch.Size([8, 64, 40, 40])
# appended
# input -> output torch.Size([8, 64, 40, 40]) torch.Size([8, 128, 20, 20])
# down    2  shape  torch.Size([8, 128, 20, 20])
# appended
# input -> output torch.Size([8, 128, 20, 20]) torch.Size([8, 256, 10, 10])
# down    3  shape  torch.Size([8, 256, 10, 10])
# appended
# input -> output torch.Size([8, 256, 10, 10]) torch.Size([8, 512, 5, 5])
# down    4  shape  torch.Size([8, 512, 5, 5])
# x_from_compressing_path torch.Size([8, 256, 10, 10])
# x_to_upconv torch.Size([8, 512, 5, 5])
# after_upconv torch.Size([8, 256, 10, 10])
# after concat torch.Size([8, 512, 10, 10])
# ch_in 512
# up      0  shape  torch.Size([8, 256, 10, 10])
# x_from_compressing_path torch.Size([8, 128, 20, 20])
# x_to_upconv torch.Size([8, 256, 10, 10])
# after_upconv torch.Size([8, 128, 20, 20])
# after concat torch.Size([8, 256, 20, 20])
# ch_in 256
# up      1  shape  torch.Size([8, 128, 20, 20])
# x_from_compressing_path torch.Size([8, 64, 40, 40])
# x_to_upconv torch.Size([8, 128, 20, 20])
# after_upconv torch.Size([8, 64, 40, 40])
# after concat torch.Size([8, 128, 40, 40])
# ch_in 128
# up      2  shape  torch.Size([8, 64, 40, 40])
# x_from_compressing_path torch.Size([8, 32, 80, 80])
# x_to_upconv torch.Size([8, 64, 40, 40])
# after_upconv torch.Size([8, 32, 80, 80])
# after concat torch.Size([8, 64, 80, 80])
# ch_in 64
# up      3  shape  torch.Size([8, 32, 80, 80])

# %%
with torch.no_grad():
    imgs_in = imgs_in[:2]
    #vae.inference.box_nms.overlap_threshold=0.2
    no_corr_topk_only, kl = vae.inference_and_generator.forward(imgs_in,
                                                                prob_corr_factor=0.0,
                                                                disk_corr_factor=1.0,
                                                                overlap_threshold=0.2,
                                                                score_threshold=-1.0,
                                                                randomize_nms_factor=0.1,
                                                                n_objects_max=6,
                                                                topk_only=True,
                                                                noisy_sampling=False)
    
    no_corr_with_nms, kl = vae.inference_and_generator.forward(imgs_in,
                                                               prob_corr_factor=0.0,
                                                               disk_corr_factor=1.0,
                                                               overlap_threshold=0.2,
                                                               score_threshold=-1.0,
                                                               randomize_nms_factor=0.1,
                                                               n_objects_max=6,
                                                               topk_only=False,
                                                               noisy_sampling=False)
    
    with_corr_topk_only, kl  = vae.inference_and_generator.forward(imgs_in,
                                                                   prob_corr_factor=1.0,
                                                                   disk_corr_factor=1.0,
                                                                   overlap_threshold=0.2,
                                                                   score_threshold=-1.0,
                                                                   randomize_nms_factor=0.1,
                                                                   n_objects_max=6,
                                                                   topk_only=True,
                                                                   noisy_sampling=False)
    
    with_corr_with_nms, kl = vae.inference_and_generator.forward(imgs_in,
                                                                 prob_corr_factor=1.0,
                                                                 disk_corr_factor=0.0,
                                                                 overlap_threshold=0.2,
                                                                 score_threshold=-1.0,
                                                                 randomize_nms_factor=0.1,
                                                                 n_objects_max=6,
                                                                 topk_only=False,
                                                                 noisy_sampling=False)

    w,h = imgs_in.shape[-2:]
    print("imgs_in.shape",imgs_in.shape)
    print("prob.shape",no_corr_topk_only.prob.shape)
    
    bb_no_corr_topk_only = vae.draw_bounding_boxes(prob = no_corr_topk_only.prob, 
                                                   bounding_box = no_corr_topk_only.bounding_box,
                                                   width = w,
                                                   height = h)
    bb_no_corr_with_nms  = vae.draw_bounding_boxes(prob = no_corr_with_nms.prob,
                                                   bounding_box = no_corr_with_nms.bounding_box,
                                                   width = w,
                                                   height = h)
    bb_with_corr_topk_only = vae.draw_bounding_boxes(prob = with_corr_topk_only.prob,
                                                     bounding_box = with_corr_topk_only.bounding_box,
                                                     width = w,
                                                     height = h)
    bb_with_corr_with_nms  = vae.draw_bounding_boxes(prob = with_corr_with_nms.prob,
                                                     bounding_box = with_corr_with_nms.bounding_box,
                                                     width = w,
                                                     height = h)
    
    imgs_no_corr_topk_only = bb_no_corr_topk_only + imgs_in
    imgs_no_corr_with_nms  = bb_no_corr_with_nms  + imgs_in
    imgs_with_corr_topk_only = bb_with_corr_topk_only + imgs_in
    imgs_with_corr_with_nms  = bb_with_corr_with_nms  + imgs_in
    
how_many_to_show = 1    
imgs_comparison = torch.cat((imgs_no_corr_topk_only[:how_many_to_show],
                             imgs_no_corr_with_nms[:how_many_to_show],
                             imgs_with_corr_topk_only[:how_many_to_show],
                             imgs_with_corr_with_nms[:how_many_to_show]),dim=0)   

print("imgs_comparison.shape ------------->",imgs_comparison.shape)
print("no_corr_topk_only.prob[:,0]",no_corr_topk_only.prob[:,0].view(-1))
print("no_corr_with_nms.prob[:,0]",no_corr_with_nms.prob[:,0].view(-1))
print("with_corr_topk_only.prob[:,0]",with_corr_topk_only.prob[:,0].view(-1))
print("with_corr_with_nms.prob[:,0]",with_corr_with_nms.prob[:,0].view(-1))
show_batch(imgs_comparison,n_col=2,n_padding=10,title="Proposal of untrained inference network")
# Out:
# imgs_in.shape torch.Size([2, 1, 80, 80])
# prob.shape torch.Size([6, 2])
# imgs_comparison.shape -------------> torch.Size([4, 3, 80, 80])
# no_corr_topk_only.prob[:,0] tensor([0.6176, 0.6280, 0.6032, 0.6015, 0.6086, 0.5898], device='cuda:0')
# no_corr_with_nms.prob[:,0] tensor([0.5883, 0.6176, 0.6032, 0.5859, 0.5870, 0.6181], device='cuda:0')
# with_corr_topk_only.prob[:,0] tensor([0.9753, 0.9277, 0.9046, 0.8821, 0.9512, 0.8385], device='cuda:0')
# with_corr_with_nms.prob[:,0] tensor([0.9753, 0.8385, 0.7969, 0.4595, 0.3798, 0.3041], device='cuda:0')

# %% [markdown]
# # Check masks

# %%
big_mask = with_corr_with_nms.big_mask
print(big_mask.shape)
mymin = torch.min(big_mask).item()
mymax = torch.max(big_mask).item()
print(mymin, mymax)
show_batch(big_mask[:,0], title="# big masks")
# Out:
# torch.Size([6, 2, 1, 80, 80])
# 0.0 0.5942373871803284

# %%
sum_big_masks = torch.sum(big_mask, dim=-5)
print(sum_big_masks.shape)
mymin = torch.min(sum_big_masks).item()
mymax = torch.max(sum_big_masks).item()
print(mymin, mymax)
show_batch(sum_big_masks)
# Out:
# torch.Size([2, 1, 80, 80])
# 0.0 0.8766520023345947

# %% [markdown]
# # Check imgs

# %%
print(with_corr_with_nms.big_img.shape)
mymin = torch.min(with_corr_with_nms.big_img).item()
mymax = torch.max(with_corr_with_nms.big_img).item()
print(mymin, mymax)
show_batch(with_corr_with_nms.big_img[:,0], title="# big img")
# Out:
# torch.Size([6, 2, 1, 80, 80])
# 0.0 0.5189434885978699

# %%
tmp = torch.sum(with_corr_with_nms.big_img, dim=-5)
mymin = torch.min(tmp).item()
mymax = torch.max(tmp).item()
print(mymin, mymax)
show_batch(tmp, title="big img")
# Out:
# 0.0 1.013808250427246

# %%
tmp = torch.sum(with_corr_with_nms.big_img * with_corr_with_nms.big_mask, dim=-5)
mymin = torch.min(tmp).item()
mymax = torch.max(tmp).item()
print(mymin, mymax)
show_batch(tmp, title="big img * big_mask")
# Out:
# 0.0 0.4420381188392639

# %% [markdown]
# ## Global parameters

# %%
TEST_FREQUENCY = 5
WRITE_FREQUENCY = 5
smoke_test= False
if(smoke_test):
    pyro.enable_validation(False)
    pyro.distributions.enable_validation(True)
    NUM_EPOCHS = 6 
else:
    pyro.enable_validation(False)
    pyro.distributions.enable_validation(False)
    NUM_EPOCHS = 50001
    
# setup the optimizer
def per_param_args(module_name, param_name):
    if 'geco_x' in param_name or 'geco_x' in module_name:
        return {"lr": vae.geco_dict["base_lr"], "betas" : vae.geco_dict["betas"], "eps" : vae.geco_dict["eps"]}  # this is short memory
    else:
        return {"lr": vae.loss_dict["base_lr"], "betas": vae.loss_dict["betas"], "eps" : vae.loss_dict["eps"]}
    
scheduler_is_active = True
if scheduler_is_active:
    scheduler_args = {'optimizer': torch.optim.Adam, 
                      'step_size' : 100, 'gamma' : 0.75, 
                      'optim_args' : per_param_args}
    scheduler = pyro.optim.StepLR(scheduler_args)
    svi = SVI(vae.model, vae.guide, scheduler, loss=Trace_ELBO(max_plate_nesting=1))
else:
    optimizer = pyro.optim.Adam(per_param_args)
    svi = SVI(vae.model, vae.guide, optimizer, loss=Trace_ELBO(max_plate_nesting=1))

# %%
gamma=0.75
x = 1
a = [x]
for n in range(10):
    x *= gamma
    a.append(x)
    
plt.plot(a)
plt.grid()

# %% [markdown]
# # Actual train loop

# %%
### training loop
#epoch_restart = 500
for delta_epoch in range(1,NUM_EPOCHS+1):
    epoch = delta_epoch+epoch_restart
    vae.train()   
    
    vae.is_geco_selftuning = (epoch > 100)
    vae.geco_goal = linear_interpolation(epoch, 
                                         values=hyper_params["GECO"]["goal"],
                                         times=hyper_params["GECO"]["times"])
    
    #vae.is_geco_selftuning = (epoch > hyper_params["GECO"]["initial_time"])
    #vae.geco_goal = hyper_params["GECO"]["goal"]
    #vae.is_geco_selftuning = (epoch > 100)
    #vae.geco_goal = 1.0
    #vae.geco_goal = linear_interpolation(epoch, 
    #                                     values=[2.0, 1.0],
    #                                     times=[100, 400])
    
    #vae.is_geco_selftuning = False
    #vae.geco_mu_detached = linear_interpolation(epoch, 
    #                                            values=[0.95,0.5],
    #                                            times=[100,500])
    
    vae.prob_corr_factor=linear_interpolation(epoch, 
                                              values=hyper_params["training_prob_corr_factor"]["values"],
                                              times=hyper_params["training_prob_corr_factor"]["times"])
    
    vae.disk_corr_factor=linear_interpolation(epoch, 
                                              values=hyper_params["training_disk_corr_factor"]["values"],
                                              times=hyper_params["training_disk_corr_factor"]["times"])
        
    #with torch.autograd.set_detect_anomaly(True):
    with torch.autograd.set_detect_anomaly(False):
        loss = train_one_epoch(svi, train_dataset, batch_size, verbose=(delta_epoch==1))
    if scheduler_is_active:
        scheduler.step(epoch=epoch)
     
    try: 
        history_dict["train_loss"].append(loss)    
        history_dict["geco_mu"].append(vae.geco_mu_detached.item())
    except KeyError:
        history_dict["train_loss"] = [loss]
        history_dict["geco_mu"] = [vae.geco_mu_detached.item()] 

    #print("geco_goal, geco_mu", vae.geco_goal, vae.geco_mu_detached.item())
    print("geco_mu geco_goal", vae.geco_mu_detached.item(), vae.geco_goal)
    
    for k,v in vae.input_dict.items():
        try:
            history_dict[k].append(v.item())
        except KeyError:
            history_dict[k] = [v.item()]
    for k,v in vae.ma_dict.items():
        try:
            history_dict[k+"_MA"].append(v.item())
        except KeyError:
            history_dict[k+"_MA"] = [v.item()]
            
    print("[epoch %03d] train loss: %.4f NLL: %.4f prob_factor %.4f disk_factor %.4f" % (epoch, loss, history_dict["nll_total_raw"][-1], vae.prob_corr_factor, vae.disk_corr_factor))

            
    if(epoch % TEST_FREQUENCY == 0):
        vae.eval()
        results_clean = vae.check_accuracy(test_dataset, batch_size, clean=True)
        results_noisy = vae.check_accuracy(test_dataset, batch_size, clean=False)
        
        loss_clean = results_clean.loss.item()
        accuracy_clean = results_clean.n_corrects/(results_clean.n_corrects+results_clean.n_errors)
        n_obj_clean = results_clean.n_objects.item()
        
        loss_noisy = results_noisy.loss.item()
        accuracy_noisy = results_noisy.n_corrects/(results_noisy.n_corrects+results_noisy.n_errors)
        n_obj_noisy = results_noisy.n_objects.item()
        
        print("[epoch %03d] test clean: %.4f accuracy: %.4f n_obj: %.4f" % (epoch, loss_clean, accuracy_clean, n_obj_clean))
        print("[epoch %03d] test noisy: %.4f accuracy: %.4f n_obj: %.4f" % (epoch, loss_noisy, accuracy_noisy, n_obj_noisy))
              
        try:
            history_dict["test_loss_clean"].append(loss_clean)
            history_dict["accuracy_clean"].append(accuracy_clean)
            history_dict["n_obj_clean"].append(n_obj_clean)
            history_dict["test_loss_noisy"].append(loss_noisy)
            history_dict["accuracy_noisy"].append(accuracy_noisy)
            history_dict["n_obj_noisy"].append(n_obj_noisy)
        except KeyError:
            history_dict["test_loss_clean"] = [loss_clean]
            history_dict["accuracy_clean"] = [accuracy_clean]
            history_dict["n_obj_clean"] = [n_obj_clean]
            history_dict["test_loss_noisy"] = [loss_noisy]
            history_dict["accuracy_noisy"] = [accuracy_noisy]
            history_dict["n_obj_noisy"] = [n_obj_noisy]
            
        if((loss == min_loss) or ((epoch % WRITE_FREQUENCY) == 0)):   
            # Save on disk
            vae.save_everything(write_dir,name_vae+"_"+str(epoch))
            save_obj(history_dict,write_dir,name_history+"_"+str(epoch))
            save_dict_as_json(hyper_params,write_dir,name_hyper_params+"_"+str(epoch))
            save_dict_as_json(vae.dict_soft_constraints,write_dir,name_soft_constraints+"_"+str(epoch))
# Out:
# i =   0 train_loss=2404.17432
# i =   1 train_loss=1329.71838
# i =   2 train_loss=1481.14453
# i =   3 train_loss=1132.70190
# i =   4 train_loss=1041.42419
# i =   5 train_loss=974.61029
# i =   6 train_loss=903.64258
# i =   7 train_loss=829.04187
# i =   8 train_loss=749.97278
# i =   9 train_loss=715.30945
# i =  10 train_loss=683.18396
# i =  11 train_loss=664.58887
# i =  12 train_loss=630.87628
# i =  13 train_loss=614.85187
# i =  14 train_loss=589.04681
# i =  15 train_loss=366.27112
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 000] train loss: 7.5553 NLL: 3.8364 prob_factor 0.5000 disk_factor 0.5000
# [epoch 000] test clean: 4.2293 accuracy: 0.0000 n_obj: 157.0000
# [epoch 000] test noisy: 4.2127 accuracy: 0.0000 n_obj: 77.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 001] train loss: 3.9152 NLL: 3.2788 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 002] train loss: 3.5856 NLL: 3.4536 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 003] train loss: 3.5092 NLL: 3.2683 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 004] train loss: 3.4693 NLL: 3.1006 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 005] train loss: 3.4285 NLL: 3.1650 prob_factor 0.5000 disk_factor 0.5000
# [epoch 005] test clean: 3.4435 accuracy: 0.0020 n_obj: 262.0000
# [epoch 005] test noisy: 3.4830 accuracy: 0.0020 n_obj: 181.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 006] train loss: 3.3890 NLL: 3.1589 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 007] train loss: 3.3580 NLL: 3.0795 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 008] train loss: 3.3205 NLL: 3.0367 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 009] train loss: 3.2445 NLL: 2.8677 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 010] train loss: 3.1414 NLL: 2.7796 prob_factor 0.5000 disk_factor 0.5000
# [epoch 010] test clean: 3.0746 accuracy: 0.0620 n_obj: 764.0000
# [epoch 010] test noisy: 3.1256 accuracy: 0.0480 n_obj: 692.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 011] train loss: 3.0485 NLL: 2.6946 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 012] train loss: 3.0156 NLL: 2.6639 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 013] train loss: 2.9972 NLL: 2.7157 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 014] train loss: 2.9805 NLL: 2.5714 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 015] train loss: 2.9993 NLL: 2.7215 prob_factor 0.5000 disk_factor 0.5000
# [epoch 015] test clean: 2.9672 accuracy: 0.6600 n_obj: 1535.0000
# [epoch 015] test noisy: 3.0186 accuracy: 0.5080 n_obj: 1417.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 016] train loss: 2.9711 NLL: 2.6458 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 017] train loss: 2.9675 NLL: 2.6514 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 018] train loss: 2.9741 NLL: 2.7248 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 019] train loss: 2.9699 NLL: 2.7275 prob_factor 0.5000 disk_factor 0.5000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 020] train loss: 2.9593 NLL: 2.6676 prob_factor 0.5000 disk_factor 0.5000
# [epoch 020] test clean: 3.0129 accuracy: 0.3560 n_obj: 1298.0000
# [epoch 020] test noisy: 3.0669 accuracy: 0.2540 n_obj: 1131.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 021] train loss: 2.9537 NLL: 2.5960 prob_factor 0.4833 disk_factor 0.4833
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 022] train loss: 2.8625 NLL: 2.5551 prob_factor 0.4667 disk_factor 0.4667
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 023] train loss: 2.8438 NLL: 2.5834 prob_factor 0.4500 disk_factor 0.4500
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 024] train loss: 2.7837 NLL: 2.4192 prob_factor 0.4333 disk_factor 0.4333
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 025] train loss: 2.6773 NLL: 2.4392 prob_factor 0.4167 disk_factor 0.4167
# [epoch 025] test clean: 2.7404 accuracy: 0.8280 n_obj: 1656.0000
# [epoch 025] test noisy: 2.7782 accuracy: 0.7960 n_obj: 1641.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 026] train loss: 2.6238 NLL: 2.3705 prob_factor 0.4000 disk_factor 0.4000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 027] train loss: 2.5750 NLL: 2.2378 prob_factor 0.3833 disk_factor 0.3833
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 028] train loss: 2.5386 NLL: 2.2624 prob_factor 0.3667 disk_factor 0.3667
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 029] train loss: 2.5136 NLL: 2.2078 prob_factor 0.3500 disk_factor 0.3500
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 030] train loss: 2.4669 NLL: 2.1594 prob_factor 0.3333 disk_factor 0.3333
# [epoch 030] test clean: 2.4072 accuracy: 0.8700 n_obj: 1679.0000
# [epoch 030] test noisy: 2.4418 accuracy: 0.8660 n_obj: 1677.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 031] train loss: 2.3783 NLL: 2.1195 prob_factor 0.3167 disk_factor 0.3167
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 032] train loss: 2.3007 NLL: 2.0003 prob_factor 0.3000 disk_factor 0.3000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 033] train loss: 2.2330 NLL: 1.9332 prob_factor 0.2833 disk_factor 0.2833
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 034] train loss: 2.1976 NLL: 2.0277 prob_factor 0.2667 disk_factor 0.2667
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 035] train loss: 2.1708 NLL: 1.8385 prob_factor 0.2500 disk_factor 0.2500
# [epoch 035] test clean: 2.0957 accuracy: 0.9160 n_obj: 1705.0000
# [epoch 035] test noisy: 2.1163 accuracy: 0.9300 n_obj: 1712.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 036] train loss: 2.1366 NLL: 1.8194 prob_factor 0.2333 disk_factor 0.2333
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 037] train loss: 1.9976 NLL: 1.7947 prob_factor 0.2167 disk_factor 0.2167
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 038] train loss: 1.8983 NLL: 1.6667 prob_factor 0.2000 disk_factor 0.2000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 039] train loss: 1.8348 NLL: 1.6569 prob_factor 0.1833 disk_factor 0.1833
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 040] train loss: 1.8052 NLL: 1.6252 prob_factor 0.1667 disk_factor 0.1667
# [epoch 040] test clean: 1.8063 accuracy: 0.8720 n_obj: 1683.0000
# [epoch 040] test noisy: 1.8333 accuracy: 0.8700 n_obj: 1682.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 041] train loss: 1.7955 NLL: 1.6336 prob_factor 0.1500 disk_factor 0.1500
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 042] train loss: 1.9486 NLL: 1.8216 prob_factor 0.1333 disk_factor 0.1333
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 043] train loss: 1.9173 NLL: 1.7607 prob_factor 0.1167 disk_factor 0.1167
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 044] train loss: 1.7553 NLL: 1.6136 prob_factor 0.1000 disk_factor 0.1000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 045] train loss: 1.6957 NLL: 1.4941 prob_factor 0.0833 disk_factor 0.0833
# [epoch 045] test clean: 2.0702 accuracy: 0.8000 n_obj: 1631.0000
# [epoch 045] test noisy: 2.1572 accuracy: 0.8000 n_obj: 1631.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 046] train loss: 1.6797 NLL: 1.4821 prob_factor 0.0667 disk_factor 0.0667
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 047] train loss: 1.5725 NLL: 1.4280 prob_factor 0.0500 disk_factor 0.0500
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 048] train loss: 1.4872 NLL: 1.2879 prob_factor 0.0333 disk_factor 0.0333
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 049] train loss: 1.4359 NLL: 1.2505 prob_factor 0.0167 disk_factor 0.0167
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 050] train loss: 1.6384 NLL: 1.8872 prob_factor 0.0000 disk_factor 0.0000
# [epoch 050] test clean: 2.5614 accuracy: 0.8840 n_obj: 1687.0000
# [epoch 050] test noisy: 2.6710 accuracy: 0.8740 n_obj: 1684.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 051] train loss: 1.8620 NLL: 1.5283 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 052] train loss: 1.6358 NLL: 1.3637 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 053] train loss: 1.5566 NLL: 1.3036 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 054] train loss: 2.1116 NLL: 1.9542 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 055] train loss: 1.8660 NLL: 1.6005 prob_factor 0.0000 disk_factor 0.0000
# [epoch 055] test clean: 1.9457 accuracy: 0.5760 n_obj: 1497.0000
# [epoch 055] test noisy: 1.9871 accuracy: 0.5700 n_obj: 1490.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 056] train loss: 1.7372 NLL: 1.4901 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 057] train loss: 1.7946 NLL: 1.7476 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 058] train loss: 1.9508 NLL: 1.6195 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 059] train loss: 1.7273 NLL: 1.3924 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 060] train loss: 1.6673 NLL: 1.4566 prob_factor 0.0000 disk_factor 0.0000
# [epoch 060] test clean: 1.7899 accuracy: 0.8200 n_obj: 1651.0000
# [epoch 060] test noisy: 1.9854 accuracy: 0.8400 n_obj: 1664.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 061] train loss: 1.6883 NLL: 1.3115 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 062] train loss: 1.5707 NLL: 1.3223 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 063] train loss: 1.5362 NLL: 1.2503 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 064] train loss: 1.4968 NLL: 1.2079 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 065] train loss: 1.4311 NLL: 1.1503 prob_factor 0.0000 disk_factor 0.0000
# [epoch 065] test clean: 1.3306 accuracy: 0.8940 n_obj: 1692.0000
# [epoch 065] test noisy: 1.3766 accuracy: 0.8800 n_obj: 1685.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 066] train loss: 1.3902 NLL: 1.1801 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 067] train loss: 1.4286 NLL: 1.2156 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 068] train loss: 1.5052 NLL: 1.2737 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 069] train loss: 1.4523 NLL: 1.2419 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 070] train loss: 1.3759 NLL: 1.1296 prob_factor 0.0000 disk_factor 0.0000
# [epoch 070] test clean: 1.6468 accuracy: 0.8000 n_obj: 1645.0000
# [epoch 070] test noisy: 1.7760 accuracy: 0.7760 n_obj: 1629.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 071] train loss: 1.3888 NLL: 1.1541 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 072] train loss: 1.3734 NLL: 1.1954 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 073] train loss: 1.4549 NLL: 1.1959 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 074] train loss: 1.3681 NLL: 1.1720 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 075] train loss: 1.4316 NLL: 1.2882 prob_factor 0.0000 disk_factor 0.0000
# [epoch 075] test clean: 1.5994 accuracy: 0.9340 n_obj: 1714.0000
# [epoch 075] test noisy: 1.7581 accuracy: 0.9440 n_obj: 1719.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 076] train loss: 1.5285 NLL: 1.2088 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 077] train loss: 1.4281 NLL: 1.3248 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 078] train loss: 1.4501 NLL: 1.2052 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 079] train loss: 1.4177 NLL: 1.1813 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 080] train loss: 1.3853 NLL: 1.1141 prob_factor 0.0000 disk_factor 0.0000
# [epoch 080] test clean: 1.3523 accuracy: 0.8840 n_obj: 1689.0000
# [epoch 080] test noisy: 1.3731 accuracy: 0.9000 n_obj: 1697.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 081] train loss: 1.3235 NLL: 1.1285 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 082] train loss: 1.3514 NLL: 1.1032 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 083] train loss: 1.3465 NLL: 1.1375 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 084] train loss: 1.3444 NLL: 1.1251 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 085] train loss: 1.3917 NLL: 1.1142 prob_factor 0.0000 disk_factor 0.0000
# [epoch 085] test clean: 1.3160 accuracy: 0.9180 n_obj: 1705.0000
# [epoch 085] test noisy: 1.3460 accuracy: 0.9240 n_obj: 1709.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 086] train loss: 1.2915 NLL: 1.0706 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 087] train loss: 1.3155 NLL: 1.1089 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 088] train loss: 1.2743 NLL: 1.1287 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 089] train loss: 1.3790 NLL: 1.1244 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 090] train loss: 1.3196 NLL: 1.0817 prob_factor 0.0000 disk_factor 0.0000
# [epoch 090] test clean: 1.2618 accuracy: 0.9400 n_obj: 1717.0000
# [epoch 090] test noisy: 1.2893 accuracy: 0.9480 n_obj: 1721.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 091] train loss: 1.3147 NLL: 1.1467 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 092] train loss: 1.3762 NLL: 1.1040 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 093] train loss: 1.2795 NLL: 1.0651 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 094] train loss: 1.2791 NLL: 1.1133 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 095] train loss: 1.3576 NLL: 1.1438 prob_factor 0.0000 disk_factor 0.0000
# [epoch 095] test clean: 1.4296 accuracy: 0.9640 n_obj: 1729.0000
# [epoch 095] test noisy: 1.4472 accuracy: 0.9540 n_obj: 1724.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 096] train loss: 1.3087 NLL: 1.0521 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 097] train loss: 1.3698 NLL: 1.1945 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 098] train loss: 1.3853 NLL: 1.1589 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 099] train loss: 1.3430 NLL: 1.1630 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 100] train loss: 1.4118 NLL: 1.2804 prob_factor 0.0000 disk_factor 0.0000
# [epoch 100] test clean: 1.6709 accuracy: 0.7680 n_obj: 1626.0000
# [epoch 100] test noisy: 1.8106 accuracy: 0.7080 n_obj: 1589.0000
# geco_mu geco_goal 0.949999988079071 1.2
# [epoch 101] train loss: 1.4769 NLL: 1.2281 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.949874222278595 1.2
# [epoch 102] train loss: 1.3919 NLL: 1.2078 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9492853879928589 1.2
# [epoch 103] train loss: 1.3962 NLL: 1.1656 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9488340616226196 1.2
# [epoch 104] train loss: 1.4597 NLL: 1.1315 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9479886889457703 1.2
# [epoch 105] train loss: 1.2784 NLL: 1.0830 prob_factor 0.0000 disk_factor 0.0000
# [epoch 105] test clean: 1.2333 accuracy: 0.9580 n_obj: 1726.0000
# [epoch 105] test noisy: 1.2970 accuracy: 0.9400 n_obj: 1717.0000
# geco_mu geco_goal 0.9469804763793945 1.2
# [epoch 106] train loss: 1.2875 NLL: 1.0674 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9460363984107971 1.2
# [epoch 107] train loss: 1.2870 NLL: 1.0857 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9452162384986877 1.2
# [epoch 108] train loss: 1.3046 NLL: 1.0800 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9444683194160461 1.2
# [epoch 109] train loss: 1.3125 NLL: 1.1092 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9439073204994202 1.2
# [epoch 110] train loss: 1.3808 NLL: 1.1551 prob_factor 0.0000 disk_factor 0.0000
# [epoch 110] test clean: 1.3019 accuracy: 0.9480 n_obj: 1720.0000
# [epoch 110] test noisy: 1.3777 accuracy: 0.9280 n_obj: 1711.0000
# geco_mu geco_goal 0.9432742595672607 1.2
# [epoch 111] train loss: 1.3014 NLL: 1.0338 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9424400329589844 1.2
# [epoch 112] train loss: 1.2774 NLL: 1.0446 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9417096972465515 1.2
# [epoch 113] train loss: 1.3731 NLL: 1.1341 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9411281943321228 1.2
# [epoch 114] train loss: 1.3641 NLL: 1.0884 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9404194355010986 1.2
# [epoch 115] train loss: 1.2527 NLL: 1.1074 prob_factor 0.0000 disk_factor 0.0000
# [epoch 115] test clean: 1.2840 accuracy: 0.9700 n_obj: 1732.0000
# [epoch 115] test noisy: 1.3904 accuracy: 0.9680 n_obj: 1731.0000
# geco_mu geco_goal 0.9398441314697266 1.2
# [epoch 116] train loss: 1.4290 NLL: 1.2515 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9396941065788269 1.2
# [epoch 117] train loss: 1.4675 NLL: 1.1841 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9395275115966797 1.2
# [epoch 118] train loss: 1.3633 NLL: 1.1326 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9390875697135925 1.2
# [epoch 119] train loss: 1.3494 NLL: 1.0514 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9383543133735657 1.2
# [epoch 120] train loss: 1.3497 NLL: 1.1680 prob_factor 0.0000 disk_factor 0.0000
# [epoch 120] test clean: 1.3901 accuracy: 0.9340 n_obj: 1716.0000
# [epoch 120] test noisy: 1.4854 accuracy: 0.9060 n_obj: 1701.0000
# geco_mu geco_goal 0.937710702419281 1.2
# [epoch 121] train loss: 1.4173 NLL: 1.0822 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9370267987251282 1.2
# [epoch 122] train loss: 1.3307 NLL: 1.0748 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9362094402313232 1.2
# [epoch 123] train loss: 1.3230 NLL: 1.0966 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9353975653648376 1.2
# [epoch 124] train loss: 1.3316 NLL: 1.1468 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9346703290939331 1.2
# [epoch 125] train loss: 1.3405 NLL: 1.0740 prob_factor 0.0000 disk_factor 0.0000
# [epoch 125] test clean: 1.2491 accuracy: 0.9660 n_obj: 1730.0000
# [epoch 125] test noisy: 1.3241 accuracy: 0.9440 n_obj: 1719.0000
# geco_mu geco_goal 0.9338078498840332 1.2
# [epoch 126] train loss: 1.3059 NLL: 1.0549 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9328820705413818 1.2
# [epoch 127] train loss: 1.3133 NLL: 1.0526 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9319354295730591 1.2
# [epoch 128] train loss: 1.3145 NLL: 1.1005 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9309796690940857 1.2
# [epoch 129] train loss: 1.2971 NLL: 1.0857 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9299997687339783 1.2
# [epoch 130] train loss: 1.2896 NLL: 1.1330 prob_factor 0.0000 disk_factor 0.0000
# [epoch 130] test clean: 1.3255 accuracy: 0.9080 n_obj: 1701.0000
# [epoch 130] test noisy: 1.4450 accuracy: 0.8560 n_obj: 1672.0000
# geco_mu geco_goal 0.9290398359298706 1.2
# [epoch 131] train loss: 1.3393 NLL: 1.0897 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9281074404716492 1.2
# [epoch 132] train loss: 1.3598 NLL: 1.1133 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9271529316902161 1.2
# [epoch 133] train loss: 1.2996 NLL: 1.0291 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9260257482528687 1.2
# [epoch 134] train loss: 1.3070 NLL: 1.0145 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9248772263526917 1.2
# [epoch 135] train loss: 1.3469 NLL: 1.0520 prob_factor 0.0000 disk_factor 0.0000
# [epoch 135] test clean: 1.2934 accuracy: 0.9860 n_obj: 1740.0000
# [epoch 135] test noisy: 1.3511 accuracy: 0.9780 n_obj: 1736.0000
# geco_mu geco_goal 0.9237690567970276 1.2
# [epoch 136] train loss: 1.3302 NLL: 1.0395 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9226681590080261 1.2
# [epoch 137] train loss: 1.2832 NLL: 1.0341 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.921541690826416 1.2
# [epoch 138] train loss: 1.3327 NLL: 1.0686 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9204171299934387 1.2
# [epoch 139] train loss: 1.3324 NLL: 1.0191 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.919252336025238 1.2
# [epoch 140] train loss: 1.2694 NLL: 1.0189 prob_factor 0.0000 disk_factor 0.0000
# [epoch 140] test clean: 1.2984 accuracy: 0.9880 n_obj: 1741.0000
# [epoch 140] test noisy: 1.3270 accuracy: 0.9840 n_obj: 1739.0000
# geco_mu geco_goal 0.918086051940918 1.2
# [epoch 141] train loss: 1.3235 NLL: 1.0343 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9169430732727051 1.2
# [epoch 142] train loss: 1.3234 NLL: 1.0437 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9161216616630554 1.2
# [epoch 143] train loss: 1.4401 NLL: 1.1741 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9156376719474792 1.2
# [epoch 144] train loss: 1.4205 NLL: 1.1101 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9149605631828308 1.2
# [epoch 145] train loss: 1.3262 NLL: 1.0410 prob_factor 0.0000 disk_factor 0.0000
# [epoch 145] test clean: 1.3071 accuracy: 0.9640 n_obj: 1729.0000
# [epoch 145] test noisy: 1.3430 accuracy: 0.9620 n_obj: 1727.0000
# geco_mu geco_goal 0.9140106439590454 1.2
# [epoch 146] train loss: 1.3153 NLL: 1.0446 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9129012227058411 1.2
# [epoch 147] train loss: 1.2888 NLL: 1.0630 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9118309617042542 1.2
# [epoch 148] train loss: 1.3493 NLL: 1.1095 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9108920693397522 1.2
# [epoch 149] train loss: 1.3463 NLL: 1.0748 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9099443554878235 1.2
# [epoch 150] train loss: 1.3652 NLL: 1.0774 prob_factor 0.0000 disk_factor 0.0000
# [epoch 150] test clean: 1.3196 accuracy: 0.9460 n_obj: 1720.0000
# [epoch 150] test noisy: 1.3930 accuracy: 0.9280 n_obj: 1711.0000
# geco_mu geco_goal 0.9089178442955017 1.2
# [epoch 151] train loss: 1.3624 NLL: 1.0943 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9080483913421631 1.2
# [epoch 152] train loss: 1.3939 NLL: 1.1729 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9073299169540405 1.2
# [epoch 153] train loss: 1.3692 NLL: 1.0528 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9064274430274963 1.2
# [epoch 154] train loss: 1.3083 NLL: 1.0613 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.905363917350769 1.2
# [epoch 155] train loss: 1.3308 NLL: 1.0189 prob_factor 0.0000 disk_factor 0.0000
# [epoch 155] test clean: 1.2793 accuracy: 0.9740 n_obj: 1734.0000
# [epoch 155] test noisy: 1.3228 accuracy: 0.9720 n_obj: 1733.0000
# geco_mu geco_goal 0.9041956067085266 1.2
# [epoch 156] train loss: 1.3067 NLL: 1.0315 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9029269218444824 1.2
# [epoch 157] train loss: 1.2948 NLL: 1.0542 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9017528295516968 1.2
# [epoch 158] train loss: 1.3500 NLL: 1.1038 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.9007852077484131 1.2
# [epoch 159] train loss: 1.3507 NLL: 1.0655 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.899770975112915 1.2
# [epoch 160] train loss: 1.3302 NLL: 1.0971 prob_factor 0.0000 disk_factor 0.0000
# [epoch 160] test clean: 1.3027 accuracy: 0.9840 n_obj: 1739.0000
# [epoch 160] test noisy: 1.3780 accuracy: 0.9660 n_obj: 1730.0000
# geco_mu geco_goal 0.8986935019493103 1.2
# [epoch 161] train loss: 1.3879 NLL: 1.0827 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8975713849067688 1.2
# [epoch 162] train loss: 1.3381 NLL: 1.0850 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8963690400123596 1.2
# [epoch 163] train loss: 1.3329 NLL: 1.0628 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8952862024307251 1.2
# [epoch 164] train loss: 1.3777 NLL: 1.1404 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8945586085319519 1.2
# [epoch 165] train loss: 1.4105 NLL: 1.1513 prob_factor 0.0000 disk_factor 0.0000
# [epoch 165] test clean: 1.4087 accuracy: 0.9420 n_obj: 1718.0000
# [epoch 165] test noisy: 1.4399 accuracy: 0.9340 n_obj: 1714.0000
# geco_mu geco_goal 0.8943682312965393 1.2
# [epoch 166] train loss: 1.4657 NLL: 1.2605 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8947740793228149 1.2
# [epoch 167] train loss: 1.5401 NLL: 1.2347 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8947371244430542 1.2
# [epoch 168] train loss: 1.3618 NLL: 1.1753 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.894131064414978 1.2
# [epoch 169] train loss: 1.3311 NLL: 1.0845 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8930606245994568 1.2
# [epoch 170] train loss: 1.3597 NLL: 1.0503 prob_factor 0.0000 disk_factor 0.0000
# [epoch 170] test clean: 1.5012 accuracy: 0.9160 n_obj: 1702.0000
# [epoch 170] test noisy: 1.5676 accuracy: 0.9160 n_obj: 1702.0000
# geco_mu geco_goal 0.8918589949607849 1.2
# [epoch 171] train loss: 1.3515 NLL: 1.0921 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8905611038208008 1.2
# [epoch 172] train loss: 1.3270 NLL: 1.0663 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8891973495483398 1.2
# [epoch 173] train loss: 1.3585 NLL: 1.1109 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.887986421585083 1.2
# [epoch 174] train loss: 1.3389 NLL: 1.0477 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8869183659553528 1.2
# [epoch 175] train loss: 1.4079 NLL: 1.0430 prob_factor 0.0000 disk_factor 0.0000
# [epoch 175] test clean: 1.3721 accuracy: 0.9660 n_obj: 1730.0000
# [epoch 175] test noisy: 1.4141 accuracy: 0.9740 n_obj: 1734.0000
# geco_mu geco_goal 0.8856963515281677 1.2
# [epoch 176] train loss: 1.3569 NLL: 1.0537 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8843228816986084 1.2
# [epoch 177] train loss: 1.3537 NLL: 1.0472 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8828921318054199 1.2
# [epoch 178] train loss: 1.3405 NLL: 1.1182 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8818314075469971 1.2
# [epoch 179] train loss: 1.4294 NLL: 1.1251 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8810899257659912 1.2
# [epoch 180] train loss: 1.4026 NLL: 1.2227 prob_factor 0.0000 disk_factor 0.0000
# [epoch 180] test clean: 1.4332 accuracy: 0.9820 n_obj: 1738.0000
# [epoch 180] test noisy: 1.4630 accuracy: 0.9820 n_obj: 1738.0000
# geco_mu geco_goal 0.8804520964622498 1.2
# [epoch 181] train loss: 1.3888 NLL: 1.1119 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8797074556350708 1.2
# [epoch 182] train loss: 1.3988 NLL: 1.2075 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8795070648193359 1.2
# [epoch 183] train loss: 1.4473 NLL: 1.1409 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8789910674095154 1.2
# [epoch 184] train loss: 1.3852 NLL: 1.0790 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8781285881996155 1.2
# [epoch 185] train loss: 1.4141 NLL: 1.2196 prob_factor 0.0000 disk_factor 0.0000
# [epoch 185] test clean: 1.4612 accuracy: 0.9540 n_obj: 1724.0000
# [epoch 185] test noisy: 1.4859 accuracy: 0.9380 n_obj: 1715.0000
# geco_mu geco_goal 0.8777408599853516 1.2
# [epoch 186] train loss: 1.4380 NLL: 1.1074 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8772163987159729 1.2
# [epoch 187] train loss: 1.4548 NLL: 1.1128 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8780874013900757 1.2
# [epoch 188] train loss: 1.8555 NLL: 1.5811 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8809081315994263 1.2
# [epoch 189] train loss: 1.6641 NLL: 1.3281 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.882513165473938 1.2
# [epoch 190] train loss: 1.5173 NLL: 1.2155 prob_factor 0.0000 disk_factor 0.0000
# [epoch 190] test clean: 1.5528 accuracy: 0.8920 n_obj: 1693.0000
# [epoch 190] test noisy: 1.5962 accuracy: 0.8840 n_obj: 1689.0000
# geco_mu geco_goal 0.8827878832817078 1.2
# [epoch 191] train loss: 1.4213 NLL: 1.1296 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.882347822189331 1.2
# [epoch 192] train loss: 1.4886 NLL: 1.1460 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8816080093383789 1.2
# [epoch 193] train loss: 1.4086 NLL: 1.0899 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8807767629623413 1.2
# [epoch 194] train loss: 1.5922 NLL: 1.2030 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8805121779441833 1.2
# [epoch 195] train loss: 1.5570 NLL: 1.1692 prob_factor 0.0000 disk_factor 0.0000
# [epoch 195] test clean: 1.4786 accuracy: 0.9620 n_obj: 1728.0000
# [epoch 195] test noisy: 1.5478 accuracy: 0.9580 n_obj: 1725.0000
# geco_mu geco_goal 0.8800859451293945 1.2
# [epoch 196] train loss: 1.4390 NLL: 1.1345 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8792605400085449 1.2
# [epoch 197] train loss: 1.3608 NLL: 1.1495 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8782379031181335 1.2
# [epoch 198] train loss: 1.3349 NLL: 1.1364 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8771100044250488 1.2
# [epoch 199] train loss: 1.3320 NLL: 1.0608 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8757754564285278 1.2
# [epoch 200] train loss: 1.3149 NLL: 1.1030 prob_factor 0.0000 disk_factor 0.0000
# [epoch 200] test clean: 1.3165 accuracy: 0.9560 n_obj: 1725.0000
# [epoch 200] test noisy: 1.3430 accuracy: 0.9580 n_obj: 1726.0000
# geco_mu geco_goal 0.8745939135551453 1.2
# [epoch 201] train loss: 1.2900 NLL: 1.0655 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8733338117599487 1.2
# [epoch 202] train loss: 1.3005 NLL: 1.0379 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8721676468849182 1.2
# [epoch 203] train loss: 1.3587 NLL: 1.0510 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8710553646087646 1.2
# [epoch 204] train loss: 1.3573 NLL: 1.0299 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8698844313621521 1.2
# [epoch 205] train loss: 1.3849 NLL: 1.0377 prob_factor 0.0000 disk_factor 0.0000
# [epoch 205] test clean: 1.3982 accuracy: 0.9660 n_obj: 1730.0000
# [epoch 205] test noisy: 1.4437 accuracy: 0.9580 n_obj: 1726.0000
# geco_mu geco_goal 0.8686056733131409 1.2
# [epoch 206] train loss: 1.3883 NLL: 1.0545 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8672339916229248 1.2
# [epoch 207] train loss: 1.3290 NLL: 0.9937 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8657616376876831 1.2
# [epoch 208] train loss: 1.2620 NLL: 1.0036 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8643301725387573 1.2
# [epoch 209] train loss: 1.3210 NLL: 1.0574 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.863053023815155 1.2
# [epoch 210] train loss: 1.3920 NLL: 1.0444 prob_factor 0.0000 disk_factor 0.0000
# [epoch 210] test clean: 1.3553 accuracy: 0.9920 n_obj: 1743.0000
# [epoch 210] test noisy: 1.4068 accuracy: 0.9900 n_obj: 1742.0000
# geco_mu geco_goal 0.8618472218513489 1.2
# [epoch 211] train loss: 1.3788 NLL: 1.1095 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8606241941452026 1.2
# [epoch 212] train loss: 1.3409 NLL: 1.0568 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8593494296073914 1.2
# [epoch 213] train loss: 1.3310 NLL: 1.0464 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8580771684646606 1.2
# [epoch 214] train loss: 1.3544 NLL: 1.0511 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8568547368049622 1.2
# [epoch 215] train loss: 1.3446 NLL: 1.0500 prob_factor 0.0000 disk_factor 0.0000
# [epoch 215] test clean: 1.2802 accuracy: 0.9860 n_obj: 1740.0000
# [epoch 215] test noisy: 1.3447 accuracy: 0.9720 n_obj: 1733.0000
# geco_mu geco_goal 0.8556941151618958 1.2
# [epoch 216] train loss: 1.3467 NLL: 1.1058 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.854525089263916 1.2
# [epoch 217] train loss: 1.3395 NLL: 1.0443 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8532224297523499 1.2
# [epoch 218] train loss: 1.3471 NLL: 1.0178 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8518813848495483 1.2
# [epoch 219] train loss: 1.3445 NLL: 1.0604 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8505417108535767 1.2
# [epoch 220] train loss: 1.3634 NLL: 1.0571 prob_factor 0.0000 disk_factor 0.0000
# [epoch 220] test clean: 1.3148 accuracy: 0.9820 n_obj: 1738.0000
# [epoch 220] test noisy: 1.3621 accuracy: 0.9700 n_obj: 1732.0000
# geco_mu geco_goal 0.8492247462272644 1.2
# [epoch 221] train loss: 1.3224 NLL: 1.0225 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8478888869285583 1.2
# [epoch 222] train loss: 1.3452 NLL: 1.0382 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8466569185256958 1.2
# [epoch 223] train loss: 1.3889 NLL: 1.0862 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8454826474189758 1.2
# [epoch 224] train loss: 1.3589 NLL: 1.0221 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8442868590354919 1.2
# [epoch 225] train loss: 1.3920 NLL: 1.0950 prob_factor 0.0000 disk_factor 0.0000
# [epoch 225] test clean: 1.3754 accuracy: 0.9740 n_obj: 1734.0000
# [epoch 225] test noisy: 1.4282 accuracy: 0.9660 n_obj: 1730.0000
# geco_mu geco_goal 0.843313992023468 1.2
# [epoch 226] train loss: 1.4186 NLL: 1.0697 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8422040343284607 1.2
# [epoch 227] train loss: 1.3337 NLL: 1.0621 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8409881591796875 1.2
# [epoch 228] train loss: 1.3878 NLL: 1.1048 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.839840292930603 1.2
# [epoch 229] train loss: 1.4311 NLL: 1.1269 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8388864994049072 1.2
# [epoch 230] train loss: 1.4270 NLL: 1.1013 prob_factor 0.0000 disk_factor 0.0000
# [epoch 230] test clean: 1.3713 accuracy: 0.9160 n_obj: 1703.0000
# [epoch 230] test noisy: 1.4122 accuracy: 0.9180 n_obj: 1704.0000
# geco_mu geco_goal 0.8377941250801086 1.2
# [epoch 231] train loss: 1.3597 NLL: 1.0387 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8364495635032654 1.2
# [epoch 232] train loss: 1.3500 NLL: 1.0716 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8351468443870544 1.2
# [epoch 233] train loss: 1.3985 NLL: 1.0792 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8339821100234985 1.2
# [epoch 234] train loss: 1.4094 NLL: 1.0536 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.832775890827179 1.2
# [epoch 235] train loss: 1.3659 NLL: 1.0553 prob_factor 0.0000 disk_factor 0.0000
# [epoch 235] test clean: 1.3074 accuracy: 0.9760 n_obj: 1735.0000
# [epoch 235] test noisy: 1.3561 accuracy: 0.9680 n_obj: 1731.0000
# geco_mu geco_goal 0.8315211534500122 1.2
# [epoch 236] train loss: 1.3435 NLL: 1.0929 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8303014636039734 1.2
# [epoch 237] train loss: 1.3738 NLL: 1.0534 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8290206789970398 1.2
# [epoch 238] train loss: 1.3337 NLL: 1.0231 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8275832533836365 1.2
# [epoch 239] train loss: 1.3320 NLL: 1.0197 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8260788917541504 1.2
# [epoch 240] train loss: 1.3367 NLL: 1.0419 prob_factor 0.0000 disk_factor 0.0000
# [epoch 240] test clean: 1.3201 accuracy: 0.9920 n_obj: 1743.0000
# [epoch 240] test noisy: 1.3709 accuracy: 0.9940 n_obj: 1744.0000
# geco_mu geco_goal 0.8245816230773926 1.2
# [epoch 241] train loss: 1.3669 NLL: 1.0321 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8232725262641907 1.2
# [epoch 242] train loss: 1.4378 NLL: 1.0556 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8219638466835022 1.2
# [epoch 243] train loss: 1.3934 NLL: 1.0704 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8205508589744568 1.2
# [epoch 244] train loss: 1.3236 NLL: 1.0463 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8190978765487671 1.2
# [epoch 245] train loss: 1.3411 NLL: 1.0465 prob_factor 0.0000 disk_factor 0.0000
# [epoch 245] test clean: 1.3508 accuracy: 0.9800 n_obj: 1737.0000
# [epoch 245] test noisy: 1.3990 accuracy: 0.9680 n_obj: 1731.0000
# geco_mu geco_goal 0.8175309896469116 1.2
# [epoch 246] train loss: 1.3311 NLL: 1.0628 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8158937692642212 1.2
# [epoch 247] train loss: 1.2990 NLL: 1.0275 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8143512010574341 1.2
# [epoch 248] train loss: 1.3527 NLL: 1.0790 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8128865361213684 1.2
# [epoch 249] train loss: 1.4043 NLL: 1.0352 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8114399909973145 1.2
# [epoch 250] train loss: 1.3667 NLL: 1.0254 prob_factor 0.0000 disk_factor 0.0000
# [epoch 250] test clean: 1.3357 accuracy: 0.9900 n_obj: 1742.0000
# [epoch 250] test noisy: 1.3749 accuracy: 0.9800 n_obj: 1737.0000
# geco_mu geco_goal 0.809840202331543 1.2
# [epoch 251] train loss: 1.3275 NLL: 1.0157 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8082258701324463 1.2
# [epoch 252] train loss: 1.3379 NLL: 1.0860 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8068345785140991 1.2
# [epoch 253] train loss: 1.3740 NLL: 1.1115 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.805407702922821 1.2
# [epoch 254] train loss: 1.3542 NLL: 1.0494 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8039079904556274 1.2
# [epoch 255] train loss: 1.3152 NLL: 1.0608 prob_factor 0.0000 disk_factor 0.0000
# [epoch 255] test clean: 1.2594 accuracy: 0.9840 n_obj: 1739.0000
# [epoch 255] test noisy: 1.2896 accuracy: 0.9820 n_obj: 1738.0000
# geco_mu geco_goal 0.802440881729126 1.2
# [epoch 256] train loss: 1.3040 NLL: 1.1021 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.8010048866271973 1.2
# [epoch 257] train loss: 1.3034 NLL: 1.0368 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.7994817495346069 1.2
# [epoch 258] train loss: 1.2875 NLL: 1.0458 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.7978843450546265 1.2
# [epoch 259] train loss: 1.2720 NLL: 1.0439 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.7961694598197937 1.2
# [epoch 260] train loss: 1.2938 NLL: 1.0618 prob_factor 0.0000 disk_factor 0.0000
# [epoch 260] test clean: 1.2739 accuracy: 0.9880 n_obj: 1741.0000
# [epoch 260] test noisy: 1.3050 accuracy: 0.9880 n_obj: 1741.0000
# geco_mu geco_goal 0.7944687604904175 1.2
# [epoch 261] train loss: 1.3042 NLL: 1.0381 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.7927370071411133 1.2
# [epoch 262] train loss: 1.3218 NLL: 1.0292 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.7911416888237 1.2
# [epoch 263] train loss: 1.3358 NLL: 1.0355 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.7895171046257019 1.2
# [epoch 264] train loss: 1.3406 NLL: 1.0305 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.787834107875824 1.2
# [epoch 265] train loss: 1.3379 NLL: 1.0484 prob_factor 0.0000 disk_factor 0.0000
# [epoch 265] test clean: 1.3416 accuracy: 0.9920 n_obj: 1743.0000
# [epoch 265] test noisy: 1.3755 accuracy: 0.9880 n_obj: 1741.0000
# geco_mu geco_goal 0.7861343026161194 1.2
# [epoch 266] train loss: 1.3631 NLL: 1.0175 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.784351646900177 1.2
# [epoch 267] train loss: 1.3274 NLL: 1.0534 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.782634437084198 1.2
# [epoch 268] train loss: 1.3208 NLL: 1.0424 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.7809945940971375 1.2
# [epoch 269] train loss: 1.3396 NLL: 1.0299 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.7793576121330261 1.2
# [epoch 270] train loss: 1.3072 NLL: 1.0282 prob_factor 0.0000 disk_factor 0.0000
# [epoch 270] test clean: 1.2743 accuracy: 0.9860 n_obj: 1740.0000
# [epoch 270] test noisy: 1.3268 accuracy: 0.9760 n_obj: 1735.0000
# geco_mu geco_goal 0.7777332663536072 1.2
# [epoch 271] train loss: 1.3157 NLL: 1.0498 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.7761077284812927 1.2
# [epoch 272] train loss: 1.3357 NLL: 1.0572 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.7745557427406311 1.2
# [epoch 273] train loss: 1.3334 NLL: 1.0428 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.7730892896652222 1.2
# [epoch 274] train loss: 1.3443 NLL: 1.0689 prob_factor 0.0000 disk_factor 0.0000
# geco_mu geco_goal 0.7715678215026855 1.2
# [epoch 275] train loss: 1.3556 NLL: 1.1002 prob_factor 0.0000 disk_factor 0.0000
# [epoch 275] test clean: 1.3313 accuracy: 0.9880 n_obj: 1741.0000
# [epoch 275] test noisy: 1.4090 accuracy: 0.9820 n_obj: 1737.0000

# %%
vae.input_dict

# %% [markdown]
# # Check the results

# %%
history_dict.keys()

# %%
for k,v in history_dict.items():
    print(k," -->", history_dict[k][-3:])

# %%
#plt.yscale('log')
y_shift=0
x_shift=0
sign=1
plt.plot(np.arange(x_shift, x_shift+len(history_dict["train_loss"])), sign*np.array(history_dict["train_loss"])+y_shift,'-')
plt.plot(np.arange(x_shift, x_shift+len(history_dict["test_loss_clean"])*TEST_FREQUENCY,TEST_FREQUENCY), sign*np.array(history_dict["test_loss_clean"])+y_shift, '.--')
plt.plot(np.arange(x_shift, x_shift+len(history_dict["test_loss_noisy"])*TEST_FREQUENCY,TEST_FREQUENCY), sign*np.array(history_dict["test_loss_noisy"])+y_shift, 'x--')
plt.xlabel('epoch')
plt.ylabel('LOSS = - ELBO')
plt.title('Training procedure')
#plt.ylim(ymax=2)
plt.grid(True)
plt.legend(['train', 'test_clean', 'test_noisy'])
#plt.show()
from matplotlib import pyplot as plt
plt.savefig(write_dir+name_vae+'_train.png')

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('epochs')
ax1.set_ylabel('n objects', color=color)
ax1.plot(np.arange(0, len(history_dict["n_obj_clean"])*TEST_FREQUENCY, TEST_FREQUENCY),history_dict["n_obj_clean"], 'o', color=color, label="clean")
ax1.plot(np.arange(0, len(history_dict["n_obj_noisy"])*TEST_FREQUENCY, TEST_FREQUENCY),history_dict["n_obj_noisy"], '-', color=color, label="noisy")
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid()
#ax1.set_ylim([1000,1870])
plt.legend()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('accuracy', color=color)  # we already handled the x-label with ax1
ax2.plot(np.arange(0, len(history_dict["accuracy_clean"])*TEST_FREQUENCY, TEST_FREQUENCY),history_dict["accuracy_clean"],'x', color=color, label="clean")
ax2.plot(np.arange(0, len(history_dict["accuracy_noisy"])*TEST_FREQUENCY, TEST_FREQUENCY),history_dict["accuracy_noisy"],'-', color=color, label="noisy")
ax2.tick_params(axis='y', labelcolor=color)
ax2.grid()
#ax2.set_ylim([0.97,1.0])
plt.legend()
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.savefig(write_dir+name_vae+'_accuracy_difference.png')

# %%
f = plt.figure(figsize=(20,10))
ax = f.add_subplot(221)
ax2 = f.add_subplot(222)
ax3 = f.add_subplot(223)
ax4 = f.add_subplot(224)

ax.plot(np.array(history_dict["sparsity_raw"]),'-',label='sparsity_raw')
#ax.set_ylim([0,10])
ax.grid()
ax.legend()

ax2.plot(np.array(history_dict["kl_zwhat_raw"]),'-',label='kl zwhat')
ax2.plot(np.array(history_dict["kl_zmask_raw"]),'-',label='kl zmask')
ax2.grid()
ax2.set_ylim([0,2])
ax2.legend()

#ax3.plot(history_dict["soft_cost_total_raw"],'-',label='cost total')
ax3.plot(0.1*np.array(history_dict["overlap"]),'-',label='cost overlap')
ax3.plot(history_dict["fg_pixel_fraction"],'-',label='cost fg_pixel_fraction')
ax3.plot(history_dict["prob_map_integral"],'-',label='cost prob_map_integral')
ax3.plot(history_dict["volume_mask_fraction"],'-',label='cost volume_mask_fraction')
ax3.plot(history_dict["prob_close_to_extremes"],'-',label='cost prob_close_to_extremes')
ax3.grid()
#ax3.set_ylim([0,0.2])
ax3.legend()

ax4.plot(history_dict["nll_total_raw"],'-',label='nll_tot_raw')
ax4.plot(history_dict["train_loss"],'-',label='train loss')
ax4.grid()
#ax4.set_ylim([6000,10000])
ax4.legend()

fig.tight_layout()  # otherwise the right y-label is slightly clipped

# %%
history_dict.keys()

# %%
fig, ax1 = plt.subplots()

color = 'tab:green'
ax1.set_xlabel('epochs')
ax1.set_ylabel('GECO x', color=color)
plt.plot(history_dict["geco_mu"],'.',label="geco_mu",color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid()
#ax1.set_ylim([0,1.1])
#plt.legend()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('nll_total', color=color)  # we already handled the x-label with ax1
ax2.plot(history_dict["nll_total_raw"],'-',label="nll_total_raw",color=color)
#ax2.plot(history_dict["nll_total_raw_MA"],'.--',label="nll_total_raw_MA",color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.plot([1.4]*len(history_dict["nll_total_raw"]),'-',label="threshold",color="black")
ax2.plot([1.0]*len(history_dict["nll_total_raw"]),'-',label="threshold",color="black")
#ax2.set_ylim([0,2])
#ax2.set_xlim([0,1])
ax2.grid()
#plt.legend()
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.savefig(write_dir+name_vae+'_geco_mu.png')

# %%
# Plot of KL vs evidence
fontsize=20
labelsize=20

how_many = 400
scale= 1
N = len(history_dict["nll_total_raw"][-how_many :])
colors = np.arange(0.0,N,1.0)/N

#plt.yscale('log')
#plt.xlim(xmin=1.0, xmax=1.5)
plt.xlabel('REC',fontsize=fontsize)
plt.ylabel('REG',fontsize=fontsize)
plt.tick_params(axis='both', which='major', labelsize=labelsize)
plt.scatter(history_dict["nll_total_raw"][-how_many :], history_dict["kl_total_raw"][-how_many :],c=colors)
plt.plot(history_dict["nll_total_raw"][-how_many :], history_dict["kl_total_raw"][-how_many :], '-')
plt.grid()
#plt.xlim(xmax=2.5)
plt.savefig(write_dir+name_vae+'_kl_trajectory.png')

# %% [markdown]
# # Check accuracy

# %%
#epoch=100
#vae.load_everything(write_dir,name_vae+"_"+str(epoch))

accuracy_result = vae.check_accuracy(test_dataset, batch_size=8)
print("accuracy ---> ",accuracy_result.n_corrects/(accuracy_result.n_corrects+accuracy_result.n_errors))
print("difference -> ",accuracy_result.diff)
print("diff_abs ---> ",accuracy_result.diff_abs)
print("n_tested ---> ",accuracy_result.n_corrects+accuracy_result.n_errors)
print(accuracy_result.list_wrong_examples)
tmp_list = accuracy_result.list_wrong_examples 

#print(tmp_list)
#tmp_list = [219] * 8
#tmp_list = [435, 10, 219] * 3
#tmp_list = [196, 133, 24, 167, 275, 216, 451, 263, 109]
#tmp_list = [10, 311, 219]
#tmp_list = [219]*3

# %%
#tmp_list = [275]
#tmp_list = [216]
#tmp_list = [243, 435, 219, 201, 113, 83, 100, 227, 448, 140]
#tmp_list = [201, 219, 435, 83]
#tmp_list = [219, 314]*5
#tmp_list = [219, 10, 421]*3
#tmp_list = [10, 105, 24, 435, 219]*2
#tmp_list = [196, 133, 24, 167, 275, 216, 451, 263, 109]
#tmp_list =[219, 435, 83]*3
#tmp_list =[201, 219, 79, 100]*2
#tmp_list =[201, 283, 219, 435, 100, 62]*2
#tmp_list = [435]*9
#tmp_list = [10, 219, 314]
#tmp_list = [10, 219, 314, 113, 83, 100, 227, 448, 140]
#tmp_list = [226, 435, 10, 219, 113, 225]
#tmp_list = [466, 427, 219]
tmp_list = [148, 291, 1, 2, 3, 4, 5, 6, 8, 9]
tmp_list = [488, 454, 491, 347, 75, 116, 215, 301, 49, 142, 309]

# %%
from matplotlib import pyplot as mp

#name='reference_mMNIST_v2'
name='reference_disks_v3'
#name='reference_dapi'

# create image if necessary
#reference_imgs, labels=test_dataset.load(batch_size=len(accuracy_result.list_wrong_examples), indices=accuracy_result.list_wrong_examples)
#reference_imgs, labels=test_dataset.load(batch_size=2, indices=accuracy_result.list_wrong_examples)
#reference_imgs, labels=test_dataset.load(batch_size=8)
#reference_imgs, labels=test_dataset.load(batch_size=9)
reference_imgs, labels=test_dataset.load(batch_size=9, indices=tmp_list)
save_obj(reference_imgs ,reference_dir,name)

reference_imgs = load_obj(reference_dir,name)
b = show_batch(reference_imgs[:],n_col=3,n_padding=4,title="REFERENCE")
b.savefig(write_dir+name+'_reference.png')
display(b)

# %% [markdown]
# # Clean vs Noisy reconstruction

# %%
print("clean reconstruction")
output_clean = vae.reconstruct_img(reference_imgs,draw_bounding_box=True,verbose=True, chosen=0)

print("-")
print("---------")
print("-")

print("noisy reconstruction")
noisy_sampling, overlap_threshold, randomize_nms_factor= True, 0.5, 0.2
output_noisy = vae.reconstruct_img(reference_imgs,
                                   draw_bounding_box=True,
                                   verbose=True, 
                                   chosen=0,
                                   prob_corr_factor=None,
                                   disk_corr_factor=None,
                                   overlap_threshold=overlap_threshold,
                                   score_threshold=None,
                                   randomize_nms_factor=randomize_nms_factor,
                                   n_objects_max=None,
                                   topk_only=False,
                                   noisy_sampling=noisy_sampling)

# %%
pmap_noisy = show_batch(output_noisy.inference.p_map, n_col=3,n_padding=4,title="Noisy Prob MAP")
pmap_clean = show_batch(output_clean.inference.p_map, n_col=3,n_padding=4,title="Clean Prob MAP")

counts_clean = torch.sum(output_clean.inference.prob>0.5,dim=0).view(-1).cpu().numpy().tolist()
rec_clean = show_batch(output_clean.rec_img[:],n_col=3,n_padding=4,title="# CLEAN "+str(counts_clean))

counts_noisy = torch.sum(output_noisy.inference.prob>0.5,dim=0).view(-1).cpu().numpy().tolist()
rec_noisy = show_batch(output_noisy.rec_img[:],n_col=3,n_padding=4,title="# NOISY "+str(counts_noisy))

background = show_batch(output_clean.inference.bg_mu,n_col=3,n_padding=4,title="BACKGROUND")
reference = show_batch(reference_imgs[:],n_col=3,n_padding=4,title="REFERENCE")

# %%
display(background, reference)

# %%
print(output_noisy.inference.p_map.sum(dim=(-1,-2,-3)).cpu())
print(output_clean.inference.p_map.sum(dim=(-1,-2,-3)).cpu())

# %%
display(rec_clean,reference)
display(rec_noisy,reference)

# %%
display(pmap_clean,reference)
display(pmap_noisy,reference)

# %%
chosen = 1 
plt.imshow(output_noisy.inference.p_map[chosen,0].cpu().numpy())
_ = plt.colorbar()
print(torch.topk(output_noisy.inference.p_map[chosen,0].view(-1), k=10, largest=True, sorted=True)[0])

# %%
plt.imshow(output_clean.inference.p_map[chosen,0].cpu().numpy())
_ = plt.colorbar()
print(torch.topk(output_clean.inference.p_map[chosen,0].view(-1), k=10, largest=True, sorted=True)[0])

# %%
_ = plt.hist(output_noisy.inference.p_map[0,0].view(-1).cpu().numpy(), density=True, bins=50)

# %%
_ = plt.hist(output_clean.inference.p_map[0,0].view(-1).cpu().numpy(), density=True, bins=50)

# %% [markdown]
# # Visualize one chosen image in details

# %%
output = output_noisy
chosen=0
how_many_to_show=20
counts = torch.sum(output.inference.prob>0.5,dim=0).view(-1).cpu().numpy().tolist()
prob_tmp = np.round(output.inference.prob[:how_many_to_show,chosen].view(-1).cpu().numpy(),decimals=4)*10000
prob_title = (prob_tmp.astype(int)/10000).tolist()
print("counts ->",counts[chosen]," prob ->",prob_title)

# %%
tmp1 = reference_imgs[chosen]
tmp2 = torch.sum(output.inference.big_img[:how_many_to_show,chosen],dim=0)
tmp3 = torch.sum(output.inference.big_mask[:how_many_to_show,chosen],dim=0)
mask_times_imgs = output.inference.big_mask * output.inference.big_img
tmp4 = torch.sum(mask_times_imgs[:how_many_to_show,chosen],dim=0)
print("sum big_masks", torch.max(tmp3))
print("sum big_masks * big_imgs", torch.max(tmp4))
combined = torch.stack((tmp1,tmp2,tmp3,tmp4),dim=0)
print(combined.shape)
b = show_batch(combined, title="# ref, IMGS, MASKS, IMGS*MASKS")
b.savefig(write_dir+name_vae+'_ref_img_mask.png')
display(b)

# %%
print(torch.max(output.inference.small_img[0,0]))
show_batch(output.inference.small_img[-5], title="small imgs")

# %%
plt.imshow(output.inference.small_mask[0,0,0].cpu().numpy())
plt.colorbar()

# %%
print(torch.max(output.inference.small_mask[0,0]))
show_batch(output.inference.small_mask[-5], title="small masks")

# %%
show_batch(reference_imgs[chosen]+output.inference.big_mask[:how_many_to_show,chosen], n_col=6, n_padding=4,title="# MASKS over REF, p="+str(prob_title))

# %%
b = show_batch(reference_imgs[chosen]+output.inference.big_img[:how_many_to_show,chosen], n_col=3, n_padding=4,title="# IMGS over REF, p="+str(prob_title))

# %%
b_mask = output.inference.big_mask[:,chosen]
b_img = output.inference.big_img[:,chosen]
tmp = torch.cat((b_mask, b_img), dim=0)
show_batch(tmp, n_col=6, n_padding=4, title="# big mask and imgs, p="+str(prob_title))

# %% [markdown]
# # Analyze numerical value of chosen image

# %%
print(output.inference._fields)
print(output.regularization._fields)
print(output.combined._fields)

# %%
chosen=0
print(output._fields)

print('\n',"-- PROB EACH OBJ --")
print(prob_title)
        
print('\n',"-- OBJECTIVE, EVIDENCE EACH OBJECT --")
for f in output.combined._fields:
    print(f, getattr(output.combined,f)[...,chosen])
    
print('\n',"-- KL --")
for f in output.kl._fields:
    if f.endswith("obj"):
        tmp=torch.sum(getattr(output.kl,f),dim=-1)
        print(f, tmp[...,chosen])
    elif f.endswith("map"):
        tmp=getattr(output.kl,f)
    #_obj
        print(f, tmp.shape)
    #print(f, getattr(output.kl,f)[...,chosen])
        
print('\n',"-- REGULARIZATION --")
for f in output.regularization._fields:
    print(f, getattr(output.regularization,f)[...,chosen])

print('\n',"-- PROB --")
print("prob ->",prob_title)

# %% [markdown]
# ### Show the probability map

# %%
print("p_map.shape", output.inference.p_map.shape)
b = show_batch(output.inference.p_map, n_col=3, n_padding=4, title="P_map")
b.savefig(write_dir+name_vae+'_pmap.png')
display(b)

# %%
show_batch(reference_imgs, n_col=3, n_padding=4, title="ref_img")

# %%
_ = plt.imshow(output.inference.p_map[chosen,0].cpu().numpy())
_ = plt.colorbar()

# %% [markdown]
# # MAKE MOVIE

# %% [markdown]
# ### Test

# %%
epoch="xxx"
a = show_batch(reference_imgs[:9],n_col=3,n_padding=4,title="REFERENCE")
b = show_batch(output.inference.p_map[:9],n_col=3,n_padding=4,title="EPOCH = "+str(epoch))
c = show_batch(output.inference.bg_mu[:9],n_col=3,n_padding=4,title="EPOCH = "+str(epoch))
display(a,b,c)

# %% [markdown]
# # actual loop

# %%
list_of_rec_files = []
list_of_map_files = []
list_of_bg_files = []
#mpl.interactive(False)


for epoch in range(0,610,1):
    if(epoch<10):
        label ="_000"+str(epoch)
    elif(epoch<100):
        label = "_00"+str(epoch)
    elif(epoch<1000):
        label = "_0"+str(epoch)
    else:
        label = str(epoch)
    
    try:
        
        vae.load_everything(write_dir,name_vae+"_"+str(epoch))
        print(label,vae.prob_corr_factor)
        output = vae.reconstruct_img(reference_imgs,True)
        #counts = torch.sum(z_where.prob>0.5,dim=1).view(-1).cpu().numpy().tolist()
        
        b=show_batch(output.rec_img[:8],n_col=4,n_padding=4,title="EPOCH = "+str(epoch))
        name_output_rec = name_vae+label+'rec.png'
        list_of_rec_files.append(name_output_rec)
        b.savefig(write_dir+name_output_rec, bbox_inches='tight') 
        
        b=show_batch(output.inference.p_map[:8],n_col=4,n_padding=4,title="EPOCH = "+str(epoch))
        name_output_map = name_vae+label+'map.png'
        list_of_map_files.append(name_output_map)
        b.savefig(write_dir+name_output_map, bbox_inches='tight') 
        
        b=show_batch(output.inference.bg_mu[:8],n_col=4,n_padding=4,title="EPOCH = "+str(epoch))
        name_output_bg = name_vae+label+'bg.png'
        list_of_bg_files.append(name_output_bg)
        b.savefig(write_dir+name_output_bg, bbox_inches='tight')
    except:
        pass
    
print(list_of_rec_files)
print(list_of_map_files)
print(list_of_bg_files)

# %% [markdown]
# ## Check individual images

# %%
#!ls ./NEW_ARCHIVE/MNIST_simplify_zwhere_v12_vae*bg.png
#bg_filenames = !ls ./NEW_ARCHIVE/MNIST_simplify_zwhere_v12_vae*bg.png
#map_filenames = !ls ./NEW_ARCHIVE/MNIST_simplify_zwhere_v12_vae*map.png
#rec_filenames = !ls ./NEW_ARCHIVE/MNIST_simplify_zwhere_v12_vae*rec.png

# %%
# concatenate filenames and directory
rec_filenames = [write_dir+name for name in list_of_rec_files]
map_filenames = [write_dir+name for name in list_of_map_files]
bg_filenames = [write_dir+name for name in list_of_bg_files]

print(rec_filenames)
print(map_filenames)
print(bg_filenames)

# %%
def show_frame_rec(n):
    return display.Image(filename=rec_filenames[n])

def show_frame_map(n):
    return Image(filename=map_filenames[n])

def show_frame_bg(n):
    return display.Image(filename=bg_filenames[n])

def show_frame_all(n):
    a = Image(filename=bg_filenames[n])
    b = Image(filename=map_filenames[n])
    c = Image(filename=rec_filenames[n])
    return display(a,b,c)

# %%
# make a gif file
#name_movie = "baseline_new_loss_v2.gif"

movie_rec = "movie_"+name_vae+"_rec.gif"
movie_map = "movie_"+name_vae+"_map.gif"
movie_bg = "movie_"+name_vae+"_bg.gif"

frame_per_second = 2
im = mpy.ImageSequenceClip(rec_filenames, fps=frame_per_second)
im.write_gif(movie_rec, fps=frame_per_second)

im = mpy.ImageSequenceClip(map_filenames, fps=frame_per_second)
im.write_gif(movie_map, fps=frame_per_second)

im = mpy.ImageSequenceClip(bg_filenames, fps=frame_per_second)
im.write_gif(movie_bg, fps=frame_per_second)

# %%
show_batch(reference_imgs[:9],n_col=3,n_padding=4,title="REFERENCE")

# %%
flatten_pmap = output.inference.p_map[chosen].view(-1)
_ = plt.hist(flatten_pmap.cpu().numpy(), density=True, bins=50)

# %%
#movie_rec = "movie_MNIST_interaction_v8_vae_map.gif"
#movie_map = "movie_MNIST_interaction_v8_vae_rec.gif"

# %%
HTML("<img src="+movie_bg+"></img>")

# %%
HTML("<img src="+movie_rec+"></img>")

# %%
show_batch(reference_imgs[:8],n_col=4,n_padding=4,title="REFERENCE")

# %%
HTML("<img src="+movie_map+"></img>")

# %%
show_batch(reference_imgs[:8],n_col=4,n_padding=4,title="REFERENCE")

# %%
show_frame_all(0)

# %%
show_frame_all(5)

# %%
show_batch(reference_imgs[:8],n_col=4,n_padding=4,title="REFERENCE")

# %%
show_frame_all(15)

# %%
show_frame_all(20)

# %%
show_frame_all(25)

# %%
show_frame_all(30)

# %%
show_frame_all(35)

# %%
show_batch(reference_imgs[:8],n_col=4,n_padding=4,title="REFERENCE")

# %% [markdown]
# # Comparison of ELBO, GRAPH_ELBO, ENUM_ELBO

# %%
display.HTML("<img src='./COMPARISON/my_movie_traceENUM_elbo.gif'></img>")

# %%
display.HTML("<img src='./COMPARISON/my_movie_traceGRAPH_elbo.gif'></img>")

# %%
display.HTML("<img src='./COMPARISON/my_movie_trace_elbo.gif'></img>")

# %% [markdown]
# # POSTER

# %%
show_batch(reference_imgs[:9],n_col=3,n_padding=4,title="INPUT")
plt.savefig(write_dir+name+'poster_90.png')

# %%
output = vae.reconstruct_img(reference_imgs,draw_bounding_box=False,verbose=False, chosen=1)
b=show_batch(output.rec_img[:9],n_col=3,n_padding=4, title="OUTPUT")
plt.savefig(write_dir+name_vae+'_poster_91.png')

# %%
output = vae.reconstruct_img(reference_imgs,draw_bounding_box=True,verbose=False, chosen=1)
_ = show_batch(output.inference.p_map, n_col=3, n_padding=4)
_ = plt.imshow(output.inference.p_map[0,0].cpu().numpy())
plt.colorbar()
plt.savefig(write_dir+name_vae+'_poster_92.png')

# %%
# Plot of KL vs evidence
fontsize=20
labelsize=20

scale= 1
N = len(history_dict["log_evidence_total"])
colors = np.arange(0.0,N,1.0)/N

plt.scatter(history_dict["log_evidence_total"], history_dict["kl_total"],c=colors)
plt.plot(history_dict["log_evidence_total"], history_dict["kl_total"], '-')
plt.savefig(write_dir+name_vae+'_v23_kl_trajectory_poster.png')

# %%
results, kl =vae.inference_and_generator(imgs_in=reference_imgs,
                                         prob_corr_factor=vae.prob_corr_factor,
                                         overlap_threshold=vae.nms_dict["overlap_threshold"],
                                         score_threshold=vae.nms_dict["score_threshold"],
                                         randomize_nms_factor=0,
                                         n_objects_max=6,
                                         topk_only=False,
                                         noisy_sampling=True)

# %%
results.bounding_box_all.bx.shape

# %%
results.bounding_box_all
with torch.no_grad():
    sss = vae.draw_bounding_boxes(prob=results.prob_all+1, 
                                  bounding_box=results.bounding_box_all, 
                                  width=reference_imgs.shape[-2], 
                                  height=reference_imgs.shape[-1])
_ = show_batch(sss+reference_imgs)
plt.savefig(write_dir+name_vae+'_poster_93.png')

# %%
with torch.no_grad():
    sss = vae.draw_bounding_boxes(prob=results.prob+1, 
                                  bounding_box=results.bounding_box, 
                                  width=reference_imgs.shape[-2], 
                                  height=reference_imgs.shape[-1])
_ = show_batch(sss+reference_imgs)
plt.savefig(write_dir+name_vae+'_poster_94.png')

# %%
with torch.no_grad():
    sss = vae.draw_bounding_boxes(prob=results.prob, 
                                  bounding_box=results.bounding_box, 
                                  width=reference_imgs.shape[-2], 
                                  height=reference_imgs.shape[-1])
b=show_batch(sss+output.rec_img[:9],n_col=3,n_padding=4)
plt.savefig(write_dir+name_vae+'_poster_95.png')

# %% [markdown]
# # END POSTER
