# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from MODULES.vae_model import *
from MODULES.utilities_ml import process_one_epoch
from MODULES.utilities_visualization import show_batch

# Check versions
from platform import python_version
print("python_version() ---> ", python_version())
print("torch.__version__ --> ", torch.__version__)
# Out:
# python_version() --->  3.8.2
# torch.__version__ -->  1.6.0

# %%
params = load_json_as_dict("./ML_parameters.json")
vae = CompositionalVae(params)

# %%
# params

# %%
image_size = params['input_image']['size_raw_image']
b, c, w, h = 8, params['input_image']['ch_in'], image_size, image_size
imgs_in = torch.sigmoid(torch.randn(b,c,w, h))

optimizer = instantiate_optimizer(model=vae, dict_params_optimizer=params["optimizer"])

# %%
show_batch(imgs_in)

# %%
generated = vae.generate(imgs_in, draw_boxes=True)
# Out:
# AFTER NMS
# torch.Size([25, 8])
# torch.Size([25, 8])
# torch.Size([8, 1, 20, 20])
# torch.Size([8])
# torch.Size([400, 8])
# torch.Size([25, 8])

# %%
print(generated._fields)
print(generated.inference._fields)
print(generated.inference.sample_c_map.shape)
show_batch(generated.inference.sample_c_map.float())
# Out:
# ('metrics', 'inference', 'imgs')
# ('logit_map', 'logit_few', 'big_bg', 'big_img', 'big_mask', 'big_mask_NON_interacting', 'sample_c_map', 'sample_c', 'sample_bb', 'sample_zinstance', 'kl_logit', 'kl_zwhere', 'kl_zinstance')
# torch.Size([8, 1, 20, 20])

# %%
a = torch.sigmoid(torch.randn(20,3)).requires_grad_(True)
x = torch.randn(20,3) > 0 
c = x*a+~x*(1-a)

# %%
a.requires_grad
# Out:
# True

# %%
c.requires_grad
# Out:
# True

# %%
from MODULES.utilities_visualization import plot_reconstruction_and_inference, plot_segmentation

plot_reconstruction_and_inference(generated, epoch=0, prefix="gen_")
# Out:
# ---------------------------------------------------------------------------
# Uninitialized                             Traceback (most recent call last)
# <ipython-input-78-d5db9f8c3ac3> in <module>
#       1 from MODULES.utilities_visualization import plot_reconstruction_and_inference, plot_segmentation
#       2
# ----> 3 plot_reconstruction_and_inference(generated, epoch=0, prefix="gen_")
#
# ~/DAPI_unsupervised/spacetx-research/src/MODULES/utilities_visualization.py in plot_reconstruction_and_inference(output, epoch, prefix, postfix, verbose)
#     520         print("in plot_reconstruction_and_inference")
#     521
# --> 522     _ = show_batch(output.imgs[:8],
#     523                    n_col=4,
#     524                    n_padding=4,
#
# ~/DAPI_unsupervised/spacetx-research/src/MODULES/utilities_visualization.py in show_batch(images, n_col, n_padding, title, pad_value, normalize_range, figsize, experiment, neptune_name)
#     191     if neptune_name is not None:
#     192         #log_img_and_chart(name=neptune_name, fig=fig, experiment=experiment)
# --> 193         log_img_only(name=neptune_name, fig=fig, experiment=experiment)
#     194
#     195     plt.close(fig)
#
# ~/DAPI_unsupervised/spacetx-research/src/MODULES/utilities_neptune.py in log_img_only(name, fig, experiment, verbose)
#      14         print("inside log_img_only -> "+name)
#      15     _exp = experiment if experiment else neptune
# ---> 16     _exp.log_image(name, fig)
#      17     if verbose:
#      18         print("leaving log_img_only -> "+name)
#
# ~/anaconda3/envs/pyro/lib/python3.8/site-packages/neptune/__init__.py in log_image(log_name, x, y, image_name, description, timestamp)
#     339     Alias for :meth:`~neptune.experiments.Experiment.log_image`
#     340     """
# --> 341     return get_experiment().send_image(log_name, x, y, image_name, description, timestamp)
#     342
#     343
#
# ~/anaconda3/envs/pyro/lib/python3.8/site-packages/neptune/__init__.py in get_experiment()
#     246     global project
#     247     if project is None:
# --> 248         raise Uninitialized()
#     249
#     250     # pylint: disable=protected-access
#
# Uninitialized: You must initialize neptune-client first. For more information, please visit: https://github.com/neptune-ai/neptune-client#initialize-neptune

# %%
output = vae.forward(imgs_in, draw_image=True, draw_boxes=True, verbose=False)
# Out:
# AFTER NMS
# torch.Size([25, 8])
# torch.Size([25, 8])
# torch.Size([8, 1, 20, 20])
# torch.Size([8])
# torch.Size([400, 8])
# torch.Size([25, 8])

# %%
output.inference.sample_bb.bh[..., 0]
print(vae.inference_and_generator.size_min)
print(vae.inference_and_generator.size_max)
# Out:
# 5
# 20

# %%
plot_reconstruction_and_inference(output, epoch=0, prefix="rec_")
# Out:
# ---------------------------------------------------------------------------
# Uninitialized                             Traceback (most recent call last)
# <ipython-input-81-f9ef2b10966e> in <module>
# ----> 1 plot_reconstruction_and_inference(output, epoch=0, prefix="rec_")
#
# ~/DAPI_unsupervised/spacetx-research/src/MODULES/utilities_visualization.py in plot_reconstruction_and_inference(output, epoch, prefix, postfix, verbose)
#     520         print("in plot_reconstruction_and_inference")
#     521
# --> 522     _ = show_batch(output.imgs[:8],
#     523                    n_col=4,
#     524                    n_padding=4,
#
# ~/DAPI_unsupervised/spacetx-research/src/MODULES/utilities_visualization.py in show_batch(images, n_col, n_padding, title, pad_value, normalize_range, figsize, experiment, neptune_name)
#     191     if neptune_name is not None:
#     192         #log_img_and_chart(name=neptune_name, fig=fig, experiment=experiment)
# --> 193         log_img_only(name=neptune_name, fig=fig, experiment=experiment)
#     194
#     195     plt.close(fig)
#
# ~/DAPI_unsupervised/spacetx-research/src/MODULES/utilities_neptune.py in log_img_only(name, fig, experiment, verbose)
#      14         print("inside log_img_only -> "+name)
#      15     _exp = experiment if experiment else neptune
# ---> 16     _exp.log_image(name, fig)
#      17     if verbose:
#      18         print("leaving log_img_only -> "+name)
#
# ~/anaconda3/envs/pyro/lib/python3.8/site-packages/neptune/__init__.py in log_image(log_name, x, y, image_name, description, timestamp)
#     339     Alias for :meth:`~neptune.experiments.Experiment.log_image`
#     340     """
# --> 341     return get_experiment().send_image(log_name, x, y, image_name, description, timestamp)
#     342
#     343
#
# ~/anaconda3/envs/pyro/lib/python3.8/site-packages/neptune/__init__.py in get_experiment()
#     246     global project
#     247     if project is None:
# --> 248         raise Uninitialized()
#     249
#     250     # pylint: disable=protected-access
#
# Uninitialized: You must initialize neptune-client first. For more information, please visit: https://github.com/neptune-ai/neptune-client#initialize-neptune

# %%
vae
# Out:
# CompositionalVae(
#   (inference_and_generator): Inference_and_Generation(
#     (similarity_kernel_dpp): SimilarityKernel()
#     (unet): UNet(
#       (down_path): ModuleList(
#         (0): DoubleConvolutionBlock(
#           (double_conv): Sequential(
#             (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ReLU(inplace=True)
#             (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (3): ReLU(inplace=True)
#           )
#         )
#         (1): DownBlock(
#           (max_pool_layer): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (double_conv): DoubleConvolutionBlock(
#             (double_conv): Sequential(
#               (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): ReLU(inplace=True)
#             )
#           )
#         )
#         (2): DownBlock(
#           (max_pool_layer): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (double_conv): DoubleConvolutionBlock(
#             (double_conv): Sequential(
#               (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): ReLU(inplace=True)
#             )
#           )
#         )
#         (3): DownBlock(
#           (max_pool_layer): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (double_conv): DoubleConvolutionBlock(
#             (double_conv): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): ReLU(inplace=True)
#             )
#           )
#         )
#         (4): DownBlock(
#           (max_pool_layer): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (double_conv): DoubleConvolutionBlock(
#             (double_conv): Sequential(
#               (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (up_path): ModuleList(
#         (0): UpBlock(
#           (up_conv_layer): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#           (double_conv): DoubleConvolutionBlock(
#             (double_conv): Sequential(
#               (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): ReLU(inplace=True)
#             )
#           )
#         )
#         (1): UpBlock(
#           (up_conv_layer): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#           (double_conv): DoubleConvolutionBlock(
#             (double_conv): Sequential(
#               (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): ReLU(inplace=True)
#             )
#           )
#         )
#         (2): UpBlock(
#           (up_conv_layer): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#           (double_conv): DoubleConvolutionBlock(
#             (double_conv): Sequential(
#               (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): ReLU(inplace=True)
#             )
#           )
#         )
#         (3): UpBlock(
#           (up_conv_layer): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#           (double_conv): DoubleConvolutionBlock(
#             (double_conv): Sequential(
#               (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): ReLU(inplace=True)
#               (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (3): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (pred_features): MLP_1by1(
#         (mlp_1by1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (encode_zwhere): Encoder1by1(
#         (predict): MLP_1by1(
#           (mlp_1by1): Sequential(
#             (0): Conv2d(128, 66, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#             (2): Conv2d(66, 8, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#       (encode_logit): Encoder1by1(
#         (predict): MLP_1by1(
#           (mlp_1by1): Sequential(
#             (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#             (2): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#       (pred_background): PredictBackground(
#         (predict): MLP_1by1(
#           (mlp_1by1): Conv2d(5, 2, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#     (decoder_zwhere): Decoder1by1Linear(
#       (predict): Conv2d(4, 4, kernel_size=(1, 1), stride=(1, 1), groups=4)
#     )
#     (decoder_logit): Decoder1by1Linear(
#       (predict): Conv2d(1, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (decoder_zinstance): DecoderConv(
#       (upsample): Linear(in_features=5, out_features=3136, bias=True)
#       (decoder): Sequential(
#         (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): ConvTranspose2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (3): ReLU(inplace=True)
#         (4): ConvTranspose2d(32, 2, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#       )
#     )
#     (encoder_zinstance): EncoderConv(
#       (conv): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (3): ReLU(inplace=True)
#         (4): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       )
#       (compute_mu): Linear(in_features=3136, out_features=5, bias=True)
#       (compute_std): Linear(in_features=3136, out_features=5, bias=True)
#     )
#   )
# )
